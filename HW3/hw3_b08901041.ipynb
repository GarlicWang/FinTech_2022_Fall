# %%
# !nvidia-smi
# Out:
# Tue Nov 15 08:56:04 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100-SXM4-40GB      Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0    43W / 400W |      0MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
import json
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.metrics import *
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_dir = "drive/MyDrive/FinTech/HW3"
impression_path = os.path.join(data_dir, "impression_v3.json")
news_path = os.path.join(data_dir, "news_list.csv")
impression_df = pd.read_json(impression_path)
news_df = pd.read_csv(news_path)

# %% [markdown]
# ### Plotting

# %%
def plot_curve_(test_y, test_proba, model_type):
    fig, (ax1, ax2) = plt.subplots(1,2, figsize=(12,4))
    ax1.set_title(f"ROC Curve of {model_type}")
    ax1.set_xlabel("False Positive Rate")
    ax1.set_ylabel("True Positive Rate")
    ROC = roc_curve(test_y, test_proba)
    AUROC = auc(ROC[0], ROC[1])
    ax1.plot(ROC[0], ROC[1], label=f'{model_type} (AUC = {AUROC:.2f})')
    ax1.legend()
    
    ax2.set_title(f"PR Curve of {model_type}")
    ax2.set_xlabel("Recall")
    ax2.set_ylabel("Precision")
    PRC = precision_recall_curve(test_y, test_proba)
    AUPRC = auc(PRC[1], PRC[0])    ## Warning : Need to invert the axis since X coordinates must be either monotonic increasing or monotonic decreasing. The auc will not change.
    ax2.plot(PRC[1], PRC[0], label=f'{model_type} (AUC = {AUPRC:.2f})')
    ax2.legend()

# %%
def plot_confusion_matrix(test_y, test_pred_class, model_type):
    print('\n')
    ax = sns.heatmap(confusion_matrix(test_y, test_pred_class), annot=True, cmap='Blues', fmt='d')

    ax.set_title(f'{model_type} Confusion Matrix\n\n');
    ax.set_xlabel('\nPredicted Values')
    ax.set_ylabel('Actual Values');

    ax.xaxis.set_ticklabels(['0','1'])
    ax.yaxis.set_ticklabels(['0','1'])

    plt.show()

# %% [markdown]
# ### Q1 : Data Spliting

# %%
train_df = impression_df[impression_df['impression_time'] < "2022/08/08"]
valid_df = impression_df[impression_df['impression_time'] >= "2022/08/08"][impression_df['impression_time'] < "2022/08/10"]
test_df = impression_df[impression_df['impression_time'] >= "2022/08/10"]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %% [markdown]
# ### Model Setting

# %%
batch_size = 1024
n_epoch = 250
lr = 0.01
early_stop = 50
seed = 9752
device = "cuda" if torch.cuda.is_available() else "cpu"
print("device : ", device)
if not os.path.isdir('./models'):
    os.mkdir('./models')
# Out:
# device :  cuda

# %%
# fix seed
def same_seed(seed):
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)  
    np.random.seed(seed)  
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

same_seed(seed)

# %%
class CTRPredictDataset(Dataset):
    def __init__(self, data_df):
        self.x = torch.Tensor([np.array(history + [target]) for (history, target) in zip(data_df['click_seq_10_onehot'].values, data_df['target_news_onehot'].values)])
        self.y = torch.Tensor(data_df['y'].values)
        self.pos_num = sum(self.y)
    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]
    def __len__(self):
        return len(self.x)

# %%
train_dataset = CTRPredictDataset(train_df)
valid_dataset = CTRPredictDataset(valid_df)
test_dataset = CTRPredictDataset(test_df)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False, pin_memory=True)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, pin_memory=True)

print(f"train positive num : {int(train_dataset.pos_num.item())}/{len(train_dataset)}, train negative num : {len(train_dataset) - int(train_dataset.pos_num.item())}/{len(train_dataset)}")
print(f"valid positive num : {int(valid_dataset.pos_num.item())}/{len(valid_dataset)}, valid negative num : {len(valid_dataset) - int(valid_dataset.pos_num.item())}/{len(valid_dataset)}")
print(f"test positive num : {int(test_dataset.pos_num.item())}/{len(test_dataset)}, test negative num : {len(test_dataset) - int(test_dataset.pos_num.item())}/{len(test_dataset)}")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   This is separate from the ipykernel package so we can avoid doing imports until
# train positive num : 1117/105320, train negative num : 104203/105320
# valid positive num : 285/34362, valid negative num : 34077/34362
# test positive num : 117/10341, test negative num : 10224/10341

# %% [markdown]
# ### Q2, 3, 4 : Bidirectional-LSTM

# %%
lstm_model_path = "./models/lstm.ckpt"

# %%
class bi_LSTM(nn.Module):
    def __init__(self, hidden_size=128, num_layers=1):
        super(bi_LSTM, self).__init__()
        self.lstm = nn.LSTM(input_size=27, hidden_size=hidden_size, num_layers=num_layers, batch_first=True, bidirectional=True)
        self.fc = nn.Linear(hidden_size * 2, 1)
    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc(out[:,-1,:]).view(-1)
        # out = torch.sigmoid(out) 
        return out

# %%
# criterion = nn.BCELoss()
criterion = nn.BCEWithLogitsLoss(pos_weight=torch.Tensor([20]).to(device))   # use pos_weight to amplify the loss of False Negative
bi_lstm = bi_LSTM(hidden_size=128, num_layers=1)
# optimizer = torch.optim.SGD(bi_lstm.parameters(), lr=lr, momentum=0.9, nesterov=True)
# optimizer = torch.optim.SGD(bi_lstm.parameters(), lr=lr, momentum=0)
optimizer = torch.optim.Adam(bi_lstm.parameters(), lr=lr, weight_decay=0)
bi_lstm.train().to(device)
lstm_train_loss_list, lstm_valid_loss_list = [], []
lstm_train_acc_list, lstm_valid_acc_list = [], []
lowest_loss, early_stop_count = float("inf"), 0
for epoch in range(n_epoch):
    train_max_, valid_max_ = 0, 0
    train_correct, valid_correct = 0, 0
    train_loss, valid_loss = 0, 0
    for x, y in train_loader:
        optimizer.zero_grad()
        x, y = x.float().to(device), y.float().to(device)
        output = bi_lstm(x)

        train_max_item = max(torch.sigmoid(output))
        # train_max_item = max(output)
        train_max_ = max(train_max_item, train_max_)
        
        loss = criterion(output, y)
        loss.backward()
        optimizer.step()
        lstm_train_pred = [0 if i < 0.5 else 1 for i in output]
        train_loss += loss.detach().item()
        train_correct += sum(torch.Tensor(lstm_train_pred)==y.cpu().detach()).item()
    train_loss = train_loss/len(train_loader)
    lstm_train_loss_list.append(train_loss)
    train_acc = train_correct/len(train_dataset)
    lstm_train_acc_list.append(train_acc)
    
    with torch.no_grad():
        for x, y in valid_loader:
            x, y = x.float().to(device), y.float().to(device)
            output = bi_lstm(x)
            
            valid_max_item = max(torch.sigmoid(output))
            # valid_max_item = max(output)
            valid_max_ = max(valid_max_item, valid_max_)

            loss = criterion(output, y)
            lstm_valid_pred = [0 if i < 0.5 else 1 for i in output]
            valid_loss += loss.detach().item()
            valid_correct += sum(torch.Tensor(lstm_valid_pred)==y.cpu().detach()).item()
        valid_loss = valid_loss/len(valid_loader)
        lstm_valid_loss_list.append(valid_loss)
        valid_acc = valid_correct/len(valid_dataset)
        lstm_valid_acc_list.append(valid_acc)

        print("train max item = ", round(train_max_.item(), 4), ", valid max item = ", round(valid_max_.item(), 4))

        torch.save(bi_lstm.state_dict(), lstm_model_path)

        print(f"epoch {epoch+1} : train loss = {round(train_loss, 4)}, train acc = {train_correct}/{len(train_dataset)} ; valid loss = {round(valid_loss, 4)}, valid acc = {valid_correct}/{len(valid_dataset)}")
        if valid_loss < lowest_loss:
            lowest_loss = valid_loss
            early_stop_count = 0
            # torch.save(bi_lstm.state_dict(), lstm_model_path)
            # print(f"Save model at epoch {epoch+1} with valid loss = {round(valid_loss, 4)}")
        else:
            early_stop_count += 1
        
        if early_stop_count >= early_stop:
            print(f'Model is not improving, early stop at epoch {epoch+1}.')
            break

    if (epoch+1)%10 == 0:
        print(f'Epoch [{epoch+1}/{n_epoch}] : Train Loss : {round(train_loss, 4)}, Valid Loss : {round(valid_loss, 4)}')
# Out:
# train max item =  0.9364 , valid max item =  0.7082
# epoch 1 : train loss = 0.5539, train acc = 103537/105320 ; valid loss = 0.4524, valid acc = 31904/34362
# train max item =  0.8098 , valid max item =  0.8523
# epoch 2 : train loss = 0.455, train acc = 102515/105320 ; valid loss = 0.5433, valid acc = 29709/34362
# train max item =  0.8153 , valid max item =  0.8737
# epoch 3 : train loss = 0.4481, train acc = 102355/105320 ; valid loss = 0.5585, valid acc = 29485/34362
# train max item =  0.8516 , valid max item =  0.8826
# epoch 4 : train loss = 0.4457, train acc = 102319/105320 ; valid loss = 0.5671, valid acc = 29054/34362
# train max item =  0.873 , valid max item =  0.8843
# epoch 5 : train loss = 0.4444, train acc = 102280/105320 ; valid loss = 0.562, valid acc = 29090/34362
# train max item =  0.8791 , valid max item =  0.8937
# epoch 6 : train loss = 0.4423, train acc = 102380/105320 ; valid loss = 0.5672, valid acc = 28940/34362
# train max item =  0.8879 , valid max item =  0.9043
# epoch 7 : train loss = 0.4402, train acc = 102463/105320 ; valid loss = 0.57, valid acc = 28924/34362
# train max item =  0.8972 , valid max item =  0.9076
# epoch 8 : train loss = 0.4394, train acc = 102263/105320 ; valid loss = 0.5623, valid acc = 29141/34362
# train max item =  0.8972 , valid max item =  0.9208
# epoch 9 : train loss = 0.4368, train acc = 102303/105320 ; valid loss = 0.5622, valid acc = 29272/34362
# train max item =  0.9144 , valid max item =  0.9321
# epoch 10 : train loss = 0.4346, train acc = 102264/105320 ; valid loss = 0.5703, valid acc = 29593/34362
# Epoch [10/250] : Train Loss : 0.4346, Valid Loss : 0.5703
# train max item =  0.9137 , valid max item =  0.9477
# epoch 11 : train loss = 0.4331, train acc = 102266/105320 ; valid loss = 0.5618, valid acc = 29644/34362
# train max item =  0.8961 , valid max item =  0.9498
# epoch 12 : train loss = 0.4318, train acc = 102205/105320 ; valid loss = 0.5637, valid acc = 29426/34362
# train max item =  0.9111 , valid max item =  0.9471
# epoch 13 : train loss = 0.4278, train acc = 102227/105320 ; valid loss = 0.5295, valid acc = 30468/34362
# train max item =  0.9207 , valid max item =  0.9493
# epoch 14 : train loss = 0.4253, train acc = 102289/105320 ; valid loss = 0.5286, valid acc = 30718/34362
# train max item =  0.9398 , valid max item =  0.9621
# epoch 15 : train loss = 0.4215, train acc = 102266/105320 ; valid loss = 0.541, valid acc = 30336/34362
# train max item =  0.9466 , valid max item =  0.9595
# epoch 16 : train loss = 0.4187, train acc = 102305/105320 ; valid loss = 0.5332, valid acc = 30634/34362
# train max item =  0.9639 , valid max item =  0.9499
# epoch 17 : train loss = 0.4142, train acc = 102286/105320 ; valid loss = 0.5117, valid acc = 31614/34362
# train max item =  0.965 , valid max item =  0.9655
# epoch 18 : train loss = 0.4098, train acc = 102406/105320 ; valid loss = 0.5199, valid acc = 31392/34362
# train max item =  0.9914 , valid max item =  0.9552
# epoch 19 : train loss = 0.4103, train acc = 102303/105320 ; valid loss = 0.5237, valid acc = 31465/34362
# train max item =  0.9696 , valid max item =  0.9825
# epoch 20 : train loss = 0.4037, train acc = 102555/105320 ; valid loss = 0.513, valid acc = 31490/34362
# Epoch [20/250] : Train Loss : 0.4037, Valid Loss : 0.513
# train max item =  0.9887 , valid max item =  0.9727
# epoch 21 : train loss = 0.3964, train acc = 102625/105320 ; valid loss = 0.5258, valid acc = 31301/34362
# train max item =  0.9898 , valid max item =  0.9825
# epoch 22 : train loss = 0.389, train acc = 102808/105320 ; valid loss = 0.5009, valid acc = 32073/34362
# train max item =  0.985 , valid max item =  0.9816
# epoch 23 : train loss = 0.3915, train acc = 102703/105320 ; valid loss = 0.5097, valid acc = 31964/34362
# train max item =  0.9958 , valid max item =  0.9886
# epoch 24 : train loss = 0.3933, train acc = 102511/105320 ; valid loss = 0.5224, valid acc = 31612/34362
# train max item =  0.9944 , valid max item =  0.9934
# epoch 25 : train loss = 0.3871, train acc = 102687/105320 ; valid loss = 0.5186, valid acc = 32248/34362
# train max item =  0.9928 , valid max item =  0.9945
# epoch 26 : train loss = 0.3789, train acc = 102908/105320 ; valid loss = 0.5163, valid acc = 31955/34362
# train max item =  0.9927 , valid max item =  0.9869
# epoch 27 : train loss = 0.3763, train acc = 102895/105320 ; valid loss = 0.516, valid acc = 32117/34362
# train max item =  0.9946 , valid max item =  0.9946
# epoch 28 : train loss = 0.3696, train acc = 103042/105320 ; valid loss = 0.5314, valid acc = 32405/34362
# train max item =  0.9973 , valid max item =  0.9947
# epoch 29 : train loss = 0.3626, train acc = 103113/105320 ; valid loss = 0.5362, valid acc = 32313/34362
# train max item =  0.9987 , valid max item =  0.9941
# epoch 30 : train loss = 0.3605, train acc = 103127/105320 ; valid loss = 0.5371, valid acc = 32473/34362
# Epoch [30/250] : Train Loss : 0.3605, Valid Loss : 0.5371
# train max item =  0.9985 , valid max item =  0.9983
# epoch 31 : train loss = 0.3637, train acc = 103036/105320 ; valid loss = 0.5524, valid acc = 32189/34362
# train max item =  0.9987 , valid max item =  0.9987
# epoch 32 : train loss = 0.3585, train acc = 103155/105320 ; valid loss = 0.564, valid acc = 32475/34362
# train max item =  0.9994 , valid max item =  0.9962
# epoch 33 : train loss = 0.3547, train acc = 103176/105320 ; valid loss = 0.5565, valid acc = 32388/34362
# train max item =  0.9993 , valid max item =  0.9994
# epoch 34 : train loss = 0.3505, train acc = 103184/105320 ; valid loss = 0.5665, valid acc = 32090/34362
# train max item =  0.9998 , valid max item =  0.9972
# epoch 35 : train loss = 0.3509, train acc = 103129/105320 ; valid loss = 0.56, valid acc = 32145/34362
# train max item =  0.9996 , valid max item =  0.9964
# epoch 36 : train loss = 0.3488, train acc = 103157/105320 ; valid loss = 0.5698, valid acc = 32283/34362
# train max item =  0.9998 , valid max item =  0.9976
# epoch 37 : train loss = 0.3448, train acc = 103184/105320 ; valid loss = 0.5725, valid acc = 32318/34362
# train max item =  0.9998 , valid max item =  0.9978
# epoch 38 : train loss = 0.3386, train acc = 103301/105320 ; valid loss = 0.5999, valid acc = 32165/34362
# train max item =  0.9999 , valid max item =  0.9957
# epoch 39 : train loss = 0.3365, train acc = 103357/105320 ; valid loss = 0.5919, valid acc = 32401/34362
# train max item =  1.0 , valid max item =  0.997
# epoch 40 : train loss = 0.3362, train acc = 103276/105320 ; valid loss = 0.6, valid acc = 32050/34362
# Epoch [40/250] : Train Loss : 0.3362, Valid Loss : 0.6
# train max item =  0.9999 , valid max item =  0.9968
# epoch 41 : train loss = 0.3335, train acc = 103285/105320 ; valid loss = 0.6057, valid acc = 32120/34362
# train max item =  1.0 , valid max item =  0.9993
# epoch 42 : train loss = 0.3328, train acc = 103380/105320 ; valid loss = 0.6153, valid acc = 32172/34362
# train max item =  1.0 , valid max item =  0.9998
# epoch 43 : train loss = 0.3336, train acc = 103348/105320 ; valid loss = 0.6189, valid acc = 32209/34362
# train max item =  0.9999 , valid max item =  0.9995
# epoch 44 : train loss = 0.3329, train acc = 103353/105320 ; valid loss = 0.6355, valid acc = 32147/34362
# train max item =  1.0 , valid max item =  0.9994
# epoch 45 : train loss = 0.3315, train acc = 103368/105320 ; valid loss = 0.606, valid acc = 32123/34362
# train max item =  1.0 , valid max item =  0.9993
# epoch 46 : train loss = 0.3393, train acc = 103193/105320 ; valid loss = 0.5775, valid acc = 32164/34362
# train max item =  1.0 , valid max item =  0.9988
# epoch 47 : train loss = 0.3387, train acc = 103298/105320 ; valid loss = 0.6058, valid acc = 32111/34362
# train max item =  1.0 , valid max item =  0.9992
# epoch 48 : train loss = 0.3328, train acc = 103366/105320 ; valid loss = 0.6248, valid acc = 32303/34362
# train max item =  1.0 , valid max item =  0.9982
# epoch 49 : train loss = 0.3269, train acc = 103377/105320 ; valid loss = 0.6386, valid acc = 32428/34362
# train max item =  1.0 , valid max item =  0.9993
# epoch 50 : train loss = 0.326, train acc = 103482/105320 ; valid loss = 0.6419, valid acc = 32430/34362
# Epoch [50/250] : Train Loss : 0.326, Valid Loss : 0.6419
# train max item =  1.0 , valid max item =  0.9992
# epoch 51 : train loss = 0.3228, train acc = 103494/105320 ; valid loss = 0.6529, valid acc = 32607/34362
# Model is not improving, early stop at epoch 51.

# %% [markdown]
# #### Loss Curve

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(12,4))
ax1.set_title("bidirectional LSTM Loss")
ax1.set_xlabel("epoch")
ax1.set_ylabel("loss")
ax1.plot(lstm_train_loss_list, label="train loss")
ax1.plot(lstm_valid_loss_list, label="valid loss")
ax1.legend()
ax2.set_title("bidirectional LSTM Acc")
ax2.set_xlabel("epoch")
ax2.set_ylabel("acc")
ax2.plot(lstm_train_acc_list, label="train acc")
ax2.plot(lstm_valid_acc_list, label="valid acc")
ax2.legend()

# %% [markdown]
# #### ROC & PRC

# %%
bi_lstm = bi_LSTM(hidden_size=128, num_layers=1)
bi_lstm.load_state_dict(torch.load(lstm_model_path))
bi_lstm.eval().to(device)
lstm_train_loss, lstm_train_proba = 0, []
lstm_valid_loss, lstm_valid_proba = 0, []
lstm_test_loss, lstm_test_proba = 0, []
with torch.no_grad():
    for x, y in tqdm(train_loader):
        x, y = x.float().to(device), y.float().to(device)
        output = bi_lstm(x)
        loss = criterion(output, y)
        lstm_train_loss += loss.detach().item()
        lstm_train_proba += output.tolist()
    lstm_train_proba = torch.sigmoid(torch.Tensor(lstm_train_proba))
    lstm_train_pred = [1 if prob >= 0.5 else 0 for prob in lstm_train_proba]
    lstm_train_loss = lstm_train_loss/len(train_loader)
    print(f"train loss : {lstm_train_loss}")
    for x, y in tqdm(valid_loader):
        x, y = x.float().to(device), y.float().to(device)
        output = bi_lstm(x)
        loss = criterion(output, y)
        lstm_valid_loss += loss.detach().item()
        lstm_valid_proba += output.tolist()
    lstm_valid_proba = torch.sigmoid(torch.Tensor(lstm_valid_proba))
    lstm_valid_pred = [1 if prob >= 0.5 else 0 for prob in lstm_valid_proba]
    lstm_valid_loss = lstm_valid_loss/len(valid_loader)
    print(f"valid loss : {lstm_valid_loss}")
    for x, y in tqdm(test_loader):
        x, y = x.float().to(device), y.float().to(device)
        output = bi_lstm(x)
        loss = criterion(output, y)
        lstm_test_loss += loss.detach().item()
        lstm_test_proba += output.tolist()
    lstm_test_proba = torch.sigmoid(torch.Tensor(lstm_test_proba))
    lstm_test_pred = [1 if prob >= 0.5 else 0 for prob in lstm_test_proba]
    lstm_test_loss = lstm_test_loss/len(test_loader)
    print(f"test loss : {lstm_test_loss}")
# Out:
# 100%|██████████| 103/103 [00:01<00:00, 73.92it/s]
# train loss : 0.31349569819505935
# 100%|██████████| 34/34 [00:00<00:00, 75.72it/s]
# valid loss : 0.6529159090098213
# 100%|██████████| 11/11 [00:00<00:00, 89.29it/s]
# test loss : 0.6357180977409537

# %%
plot_curve_(train_dataset.y, np.array(lstm_train_proba), "bi-LSTM on train set")

# %%
plot_curve_(valid_dataset.y, np.array(lstm_valid_proba), "bi-LSTM on valid set")

# %%
plot_curve_(test_dataset.y, np.array(lstm_test_proba), "bi-LSTM on test set")

# %%
plot_confusion_matrix(test_dataset.y, lstm_test_pred, "bidirectional LSTM")

# %% [markdown]
# ### Q5 : Bidirectional-GRU

# %%
gru_model_path = "./models/gru.ckpt"

# %%
class bi_GRU(nn.Module):
    def __init__(self, hidden_size, num_layers):
        super(bi_GRU, self).__init__()
        self.gru = nn.GRU(input_size=27, hidden_size=hidden_size, num_layers=num_layers, batch_first=True, bidirectional=True)
        self.fc = nn.Linear(hidden_size * 2, 1)
    def forward(self, x):
        out, _ = self.gru(x)
        out = self.fc(out[:,-1,:]).view(-1)
        # out = torch.sigmoid(out)
        return out

# %%
# criterion = nn.BCELoss()
criterion = nn.BCEWithLogitsLoss(pos_weight=torch.Tensor([20]).to(device))   # use pos_weight to amplify the loss of False Negative
bi_gru = bi_GRU(hidden_size=128, num_layers=1)
# optimizer = torch.optim.SGD(bi_gru.parameters(), lr=lr, momentum=0.9, nesterov=True)
# optimizer = torch.optim.SGD(bi_gru.parameters(), lr=lr, momentum=0)
optimizer = torch.optim.Adam(bi_gru.parameters(), lr=lr, weight_decay=0)
bi_gru.train().to(device)
gru_train_loss_list, gru_valid_loss_list = [], []
gru_train_acc_list, gru_valid_acc_list = [], []
lowest_loss, early_stop_count = float("inf"), 0
for epoch in range(n_epoch):
    train_max_, valid_max_ = 0, 0
    train_correct, valid_correct = 0, 0
    train_loss, valid_loss = 0, 0
    for x, y in train_loader:
        optimizer.zero_grad()
        x, y = x.float().to(device), y.float().to(device)
        output = bi_gru(x)

        train_max_item = max(torch.sigmoid(output))
        # train_max_item = max(output)
        train_max_ = max(train_max_item, train_max_)
        
        loss = criterion(output, y)
        loss.backward()
        optimizer.step()
        gru_train_pred = [0 if i < 0.5 else 1 for i in output]
        train_loss += loss.detach().item()
        train_correct += sum(torch.Tensor(gru_train_pred)==y.cpu().detach()).item()
    train_loss = train_loss/len(train_loader)
    gru_train_loss_list.append(train_loss)
    train_acc = train_correct/len(train_dataset)
    gru_train_acc_list.append(train_acc)
    
    with torch.no_grad():
        for x, y in valid_loader:
            x, y = x.float().to(device), y.float().to(device)
            output = bi_gru(x)
            
            valid_max_item = max(torch.sigmoid(output))
            # valid_max_item = max(output)
            valid_max_ = max(valid_max_item, valid_max_)

            loss = criterion(output, y)
            gru_valid_pred = [0 if i < 0.5 else 1 for i in output]
            valid_loss += loss.detach().item()
            valid_correct += sum(torch.Tensor(gru_valid_pred)==y.cpu().detach()).item()
        valid_loss = valid_loss/len(valid_loader)
        gru_valid_loss_list.append(valid_loss)
        valid_acc = valid_correct/len(valid_dataset)
        gru_valid_acc_list.append(valid_acc)

        print("train max item = ", round(train_max_.item(), 4), ", valid max item = ", round(valid_max_.item(), 4))

        torch.save(bi_gru.state_dict(), gru_model_path)

        print(f"epoch {epoch+1} : train loss = {round(train_loss, 4)}, train acc = {train_correct}/{len(train_dataset)} ; valid loss = {round(valid_loss, 4)}, valid acc = {valid_correct}/{len(valid_dataset)}")
        if valid_loss < lowest_loss:
            lowest_loss = valid_loss
            early_stop_count = 0
            # torch.save(bi_gru.state_dict(), gru_model_path)
            # print(f"Save model at epoch {epoch+1} with valid loss = {round(valid_loss, 4)}")
        else:
            early_stop_count += 1
        
        if early_stop_count >= early_stop:
            print(f'Model is not improving, early stop at epoch {epoch+1}.')
            break

    if (epoch+1)%10 == 0:
        print(f'Epoch [{epoch+1}/{n_epoch}] : Train Loss : {round(train_loss, 4)}, Valid Loss : {round(valid_loss, 4)}')
# Out:
# train max item =  0.8342 , valid max item =  0.8893
# epoch 1 : train loss = 0.4923, train acc = 102126/105320 ; valid loss = 0.5553, valid acc = 29198/34362
# train max item =  0.838 , valid max item =  0.8788
# epoch 2 : train loss = 0.4536, train acc = 102280/105320 ; valid loss = 0.5413, valid acc = 29568/34362
# train max item =  0.8436 , valid max item =  0.9205
# epoch 3 : train loss = 0.4498, train acc = 102459/105320 ; valid loss = 0.5577, valid acc = 29315/34362
# train max item =  0.86 , valid max item =  0.9419
# epoch 4 : train loss = 0.4471, train acc = 102454/105320 ; valid loss = 0.5841, valid acc = 28661/34362
# train max item =  0.8856 , valid max item =  0.9575
# epoch 5 : train loss = 0.4441, train acc = 102475/105320 ; valid loss = 0.6022, valid acc = 28373/34362
# train max item =  0.9239 , valid max item =  0.9447
# epoch 6 : train loss = 0.4417, train acc = 102432/105320 ; valid loss = 0.5801, valid acc = 28697/34362
# train max item =  0.9352 , valid max item =  0.9704
# epoch 7 : train loss = 0.4407, train acc = 102552/105320 ; valid loss = 0.554, valid acc = 29723/34362
# train max item =  0.9583 , valid max item =  0.9471
# epoch 8 : train loss = 0.4392, train acc = 102639/105320 ; valid loss = 0.5228, valid acc = 30703/34362
# train max item =  0.9337 , valid max item =  0.9744
# epoch 9 : train loss = 0.4392, train acc = 102473/105320 ; valid loss = 0.5541, valid acc = 29999/34362
# train max item =  0.963 , valid max item =  0.9795
# epoch 10 : train loss = 0.4345, train acc = 102576/105320 ; valid loss = 0.566, valid acc = 29738/34362
# Epoch [10/250] : Train Loss : 0.4345, Valid Loss : 0.566
# train max item =  0.9735 , valid max item =  0.9904
# epoch 11 : train loss = 0.4302, train acc = 102582/105320 ; valid loss = 0.6134, valid acc = 28908/34362
# train max item =  0.9806 , valid max item =  0.9814
# epoch 12 : train loss = 0.4277, train acc = 102514/105320 ; valid loss = 0.5418, valid acc = 30367/34362
# train max item =  0.9864 , valid max item =  0.9923
# epoch 13 : train loss = 0.4229, train acc = 102499/105320 ; valid loss = 0.5877, valid acc = 29382/34362
# train max item =  0.9813 , valid max item =  0.9867
# epoch 14 : train loss = 0.428, train acc = 102604/105320 ; valid loss = 0.5602, valid acc = 30102/34362
# train max item =  0.9753 , valid max item =  0.9921
# epoch 15 : train loss = 0.4251, train acc = 102377/105320 ; valid loss = 0.5828, valid acc = 29938/34362
# train max item =  0.9891 , valid max item =  0.9954
# epoch 16 : train loss = 0.4176, train acc = 102511/105320 ; valid loss = 0.554, valid acc = 30377/34362
# train max item =  0.9885 , valid max item =  0.996
# epoch 17 : train loss = 0.4169, train acc = 102397/105320 ; valid loss = 0.5966, valid acc = 30211/34362
# train max item =  0.9959 , valid max item =  0.9925
# epoch 18 : train loss = 0.4171, train acc = 102329/105320 ; valid loss = 0.5715, valid acc = 30171/34362
# train max item =  0.9931 , valid max item =  0.9828
# epoch 19 : train loss = 0.4116, train acc = 102519/105320 ; valid loss = 0.5218, valid acc = 31719/34362
# train max item =  0.9884 , valid max item =  0.9863
# epoch 20 : train loss = 0.4087, train acc = 102598/105320 ; valid loss = 0.5254, valid acc = 31667/34362
# Epoch [20/250] : Train Loss : 0.4087, Valid Loss : 0.5254
# train max item =  0.9934 , valid max item =  0.9917
# epoch 21 : train loss = 0.4071, train acc = 102574/105320 ; valid loss = 0.5137, valid acc = 31847/34362
# train max item =  0.9883 , valid max item =  0.9889
# epoch 22 : train loss = 0.4146, train acc = 102371/105320 ; valid loss = 0.5332, valid acc = 30864/34362
# train max item =  0.9926 , valid max item =  0.9913
# epoch 23 : train loss = 0.4195, train acc = 102372/105320 ; valid loss = 0.5498, valid acc = 30889/34362
# train max item =  0.9859 , valid max item =  0.9927
# epoch 24 : train loss = 0.4259, train acc = 102223/105320 ; valid loss = 0.5536, valid acc = 30430/34362
# train max item =  0.9926 , valid max item =  0.9945
# epoch 25 : train loss = 0.42, train acc = 102422/105320 ; valid loss = 0.5213, valid acc = 30984/34362
# train max item =  0.9921 , valid max item =  0.9912
# epoch 26 : train loss = 0.4234, train acc = 102094/105320 ; valid loss = 0.5837, valid acc = 30550/34362
# train max item =  0.9687 , valid max item =  0.9913
# epoch 27 : train loss = 0.5148, train acc = 101164/105320 ; valid loss = 0.5874, valid acc = 29767/34362
# train max item =  0.9744 , valid max item =  0.9932
# epoch 28 : train loss = 0.4702, train acc = 101951/105320 ; valid loss = 0.6623, valid acc = 28407/34362
# train max item =  0.9737 , valid max item =  0.9868
# epoch 29 : train loss = 0.4536, train acc = 102003/105320 ; valid loss = 0.6076, valid acc = 28871/34362
# train max item =  0.9613 , valid max item =  0.9875
# epoch 30 : train loss = 0.4503, train acc = 102295/105320 ; valid loss = 0.5553, valid acc = 30014/34362
# Epoch [30/250] : Train Loss : 0.4503, Valid Loss : 0.5553
# train max item =  0.9655 , valid max item =  0.9778
# epoch 31 : train loss = 0.4505, train acc = 102379/105320 ; valid loss = 0.5322, valid acc = 31027/34362
# train max item =  0.9724 , valid max item =  0.9866
# epoch 32 : train loss = 0.4509, train acc = 102035/105320 ; valid loss = 0.5451, valid acc = 30115/34362
# train max item =  0.975 , valid max item =  0.983
# epoch 33 : train loss = 0.4446, train acc = 102221/105320 ; valid loss = 0.5217, valid acc = 30680/34362
# train max item =  0.9638 , valid max item =  0.9801
# epoch 34 : train loss = 0.4389, train acc = 102197/105320 ; valid loss = 0.5388, valid acc = 30378/34362
# train max item =  0.9683 , valid max item =  0.9913
# epoch 35 : train loss = 0.4367, train acc = 102403/105320 ; valid loss = 0.5609, valid acc = 29995/34362
# train max item =  0.9759 , valid max item =  0.9933
# epoch 36 : train loss = 0.4297, train acc = 102472/105320 ; valid loss = 0.563, valid acc = 30105/34362
# train max item =  0.9851 , valid max item =  0.992
# epoch 37 : train loss = 0.4294, train acc = 102404/105320 ; valid loss = 0.5755, valid acc = 30006/34362
# train max item =  0.9708 , valid max item =  0.987
# epoch 38 : train loss = 0.4242, train acc = 102583/105320 ; valid loss = 0.5582, valid acc = 30314/34362
# train max item =  0.9776 , valid max item =  0.9884
# epoch 39 : train loss = 0.4249, train acc = 102529/105320 ; valid loss = 0.5527, valid acc = 30397/34362
# train max item =  0.9791 , valid max item =  0.9923
# epoch 40 : train loss = 0.4267, train acc = 102600/105320 ; valid loss = 0.5614, valid acc = 30346/34362
# Epoch [40/250] : Train Loss : 0.4267, Valid Loss : 0.5614
# train max item =  0.9813 , valid max item =  0.993
# epoch 41 : train loss = 0.43, train acc = 102343/105320 ; valid loss = 0.5394, valid acc = 30890/34362
# train max item =  0.9887 , valid max item =  0.9949
# epoch 42 : train loss = 0.4363, train acc = 102183/105320 ; valid loss = 0.52, valid acc = 31096/34362
# train max item =  0.9851 , valid max item =  0.9945
# epoch 43 : train loss = 0.4333, train acc = 102172/105320 ; valid loss = 0.5741, valid acc = 29849/34362
# train max item =  0.9894 , valid max item =  0.9882
# epoch 44 : train loss = 0.4327, train acc = 102324/105320 ; valid loss = 0.5379, valid acc = 30842/34362
# train max item =  0.9843 , valid max item =  0.9954
# epoch 45 : train loss = 0.4296, train acc = 102361/105320 ; valid loss = 0.5576, valid acc = 30244/34362
# train max item =  0.9835 , valid max item =  0.9882
# epoch 46 : train loss = 0.4295, train acc = 102354/105320 ; valid loss = 0.5446, valid acc = 30433/34362
# train max item =  0.9793 , valid max item =  0.9941
# epoch 47 : train loss = 0.4304, train acc = 102496/105320 ; valid loss = 0.5481, valid acc = 30437/34362
# train max item =  0.9826 , valid max item =  0.9919
# epoch 48 : train loss = 0.4276, train acc = 102395/105320 ; valid loss = 0.5436, valid acc = 30475/34362
# train max item =  0.9851 , valid max item =  0.9932
# epoch 49 : train loss = 0.429, train acc = 102297/105320 ; valid loss = 0.5182, valid acc = 31214/34362
# train max item =  0.9799 , valid max item =  0.9928
# epoch 50 : train loss = 0.4254, train acc = 102361/105320 ; valid loss = 0.5314, valid acc = 30940/34362
# Epoch [50/250] : Train Loss : 0.4254, Valid Loss : 0.5314
# train max item =  0.9858 , valid max item =  0.9768
# epoch 51 : train loss = 0.4268, train acc = 102233/105320 ; valid loss = 0.5204, valid acc = 31579/34362
# train max item =  0.9866 , valid max item =  0.9952
# epoch 52 : train loss = 0.4285, train acc = 102295/105320 ; valid loss = 0.5776, valid acc = 29941/34362
# train max item =  0.9917 , valid max item =  0.9949
# epoch 53 : train loss = 0.4254, train acc = 102346/105320 ; valid loss = 0.5427, valid acc = 30543/34362
# train max item =  0.9864 , valid max item =  0.9964
# epoch 54 : train loss = 0.4197, train acc = 102289/105320 ; valid loss = 0.5677, valid acc = 29907/34362
# train max item =  0.9876 , valid max item =  0.9945
# epoch 55 : train loss = 0.4168, train acc = 102448/105320 ; valid loss = 0.534, valid acc = 30858/34362
# train max item =  0.9897 , valid max item =  0.9975
# epoch 56 : train loss = 0.412, train acc = 102557/105320 ; valid loss = 0.5237, valid acc = 30996/34362
# train max item =  0.9895 , valid max item =  0.9968
# epoch 57 : train loss = 0.4081, train acc = 102498/105320 ; valid loss = 0.5363, valid acc = 30949/34362
# train max item =  0.9927 , valid max item =  0.9909
# epoch 58 : train loss = 0.4086, train acc = 102519/105320 ; valid loss = 0.5392, valid acc = 30970/34362
# train max item =  0.9959 , valid max item =  0.995
# epoch 59 : train loss = 0.414, train acc = 102388/105320 ; valid loss = 0.5482, valid acc = 30967/34362
# train max item =  0.9942 , valid max item =  0.9973
# epoch 60 : train loss = 0.4129, train acc = 102428/105320 ; valid loss = 0.531, valid acc = 31117/34362
# Epoch [60/250] : Train Loss : 0.4129, Valid Loss : 0.531
# train max item =  0.9983 , valid max item =  0.9978
# epoch 61 : train loss = 0.4125, train acc = 102301/105320 ; valid loss = 0.5302, valid acc = 31581/34362
# train max item =  0.997 , valid max item =  0.9995
# epoch 62 : train loss = 0.4084, train acc = 102546/105320 ; valid loss = 0.5593, valid acc = 30789/34362
# train max item =  0.9967 , valid max item =  0.9939
# epoch 63 : train loss = 0.4205, train acc = 102024/105320 ; valid loss = 0.5475, valid acc = 31472/34362
# train max item =  0.9956 , valid max item =  0.9975
# epoch 64 : train loss = 0.42, train acc = 102395/105320 ; valid loss = 0.5473, valid acc = 30996/34362
# train max item =  0.9953 , valid max item =  0.9923
# epoch 65 : train loss = 0.4175, train acc = 102269/105320 ; valid loss = 0.5092, valid acc = 31871/34362
# train max item =  0.9917 , valid max item =  0.9931
# epoch 66 : train loss = 0.4251, train acc = 102163/105320 ; valid loss = 0.5349, valid acc = 31124/34362
# train max item =  0.9969 , valid max item =  0.9959
# epoch 67 : train loss = 0.4183, train acc = 102248/105320 ; valid loss = 0.5207, valid acc = 31449/34362
# train max item =  0.9963 , valid max item =  0.9912
# epoch 68 : train loss = 0.4141, train acc = 102474/105320 ; valid loss = 0.5372, valid acc = 31002/34362
# train max item =  0.9889 , valid max item =  0.9897
# epoch 69 : train loss = 0.4161, train acc = 102238/105320 ; valid loss = 0.5124, valid acc = 31630/34362
# train max item =  0.9962 , valid max item =  0.9937
# epoch 70 : train loss = 0.4166, train acc = 102446/105320 ; valid loss = 0.5586, valid acc = 30675/34362
# Epoch [70/250] : Train Loss : 0.4166, Valid Loss : 0.5586
# train max item =  0.9933 , valid max item =  0.9986
# epoch 71 : train loss = 0.4139, train acc = 102379/105320 ; valid loss = 0.5766, valid acc = 30064/34362
# train max item =  0.9979 , valid max item =  0.999
# epoch 72 : train loss = 0.4158, train acc = 102314/105320 ; valid loss = 0.5583, valid acc = 30609/34362
# train max item =  0.9941 , valid max item =  0.9931
# epoch 73 : train loss = 0.4069, train acc = 102510/105320 ; valid loss = 0.5349, valid acc = 31424/34362
# train max item =  0.9975 , valid max item =  0.9967
# epoch 74 : train loss = 0.4064, train acc = 102571/105320 ; valid loss = 0.5464, valid acc = 31042/34362
# train max item =  0.9971 , valid max item =  0.9955
# epoch 75 : train loss = 0.4073, train acc = 102493/105320 ; valid loss = 0.5382, valid acc = 31560/34362
# train max item =  0.9976 , valid max item =  0.9973
# epoch 76 : train loss = 0.4028, train acc = 102513/105320 ; valid loss = 0.5474, valid acc = 31038/34362
# train max item =  0.9965 , valid max item =  0.9976
# epoch 77 : train loss = 0.4061, train acc = 102507/105320 ; valid loss = 0.5444, valid acc = 31440/34362
# train max item =  0.9959 , valid max item =  0.9929
# epoch 78 : train loss = 0.4029, train acc = 102647/105320 ; valid loss = 0.5493, valid acc = 31496/34362
# train max item =  0.9975 , valid max item =  0.9982
# epoch 79 : train loss = 0.3983, train acc = 102584/105320 ; valid loss = 0.5555, valid acc = 31378/34362
# train max item =  0.9977 , valid max item =  0.9956
# epoch 80 : train loss = 0.4111, train acc = 102149/105320 ; valid loss = 0.5643, valid acc = 31443/34362
# Epoch [80/250] : Train Loss : 0.4111, Valid Loss : 0.5643
# train max item =  0.9988 , valid max item =  0.9933
# epoch 81 : train loss = 0.4081, train acc = 102352/105320 ; valid loss = 0.5694, valid acc = 31196/34362
# train max item =  0.9987 , valid max item =  0.9939
# epoch 82 : train loss = 0.4204, train acc = 102168/105320 ; valid loss = 0.5838, valid acc = 30454/34362
# train max item =  0.9984 , valid max item =  0.9985
# epoch 83 : train loss = 0.4259, train acc = 102058/105320 ; valid loss = 0.5906, valid acc = 30692/34362
# train max item =  0.9975 , valid max item =  0.9889
# epoch 84 : train loss = 0.4236, train acc = 102292/105320 ; valid loss = 0.5744, valid acc = 30516/34362
# train max item =  0.9937 , valid max item =  0.9896
# epoch 85 : train loss = 0.4212, train acc = 102266/105320 ; valid loss = 0.531, valid acc = 31518/34362
# train max item =  0.9975 , valid max item =  0.9863
# epoch 86 : train loss = 0.4064, train acc = 102610/105320 ; valid loss = 0.5555, valid acc = 31472/34362
# train max item =  0.9982 , valid max item =  0.9942
# epoch 87 : train loss = 0.4088, train acc = 102472/105320 ; valid loss = 0.5565, valid acc = 31502/34362
# train max item =  0.9989 , valid max item =  0.9973
# epoch 88 : train loss = 0.4004, train acc = 102700/105320 ; valid loss = 0.5792, valid acc = 30705/34362
# train max item =  0.999 , valid max item =  0.9979
# epoch 89 : train loss = 0.4011, train acc = 102538/105320 ; valid loss = 0.5665, valid acc = 31276/34362
# train max item =  0.9958 , valid max item =  0.997
# epoch 90 : train loss = 0.3978, train acc = 102654/105320 ; valid loss = 0.5783, valid acc = 31483/34362
# Epoch [90/250] : Train Loss : 0.3978, Valid Loss : 0.5783
# train max item =  0.9982 , valid max item =  0.9974
# epoch 91 : train loss = 0.4029, train acc = 102418/105320 ; valid loss = 0.5568, valid acc = 31792/34362
# train max item =  0.9994 , valid max item =  0.9978
# epoch 92 : train loss = 0.4082, train acc = 102332/105320 ; valid loss = 0.5779, valid acc = 30761/34362
# train max item =  0.9957 , valid max item =  0.9946
# epoch 93 : train loss = 0.4034, train acc = 102437/105320 ; valid loss = 0.5898, valid acc = 30934/34362
# train max item =  0.9975 , valid max item =  0.9955
# epoch 94 : train loss = 0.4037, train acc = 102436/105320 ; valid loss = 0.5955, valid acc = 30946/34362
# train max item =  0.9972 , valid max item =  0.9988
# epoch 95 : train loss = 0.399, train acc = 102641/105320 ; valid loss = 0.5637, valid acc = 31179/34362
# train max item =  0.9965 , valid max item =  0.9939
# epoch 96 : train loss = 0.4008, train acc = 102400/105320 ; valid loss = 0.5911, valid acc = 31326/34362
# train max item =  0.9968 , valid max item =  0.9965
# epoch 97 : train loss = 0.3928, train acc = 102672/105320 ; valid loss = 0.5914, valid acc = 31179/34362
# train max item =  0.9967 , valid max item =  0.999
# epoch 98 : train loss = 0.3879, train acc = 102701/105320 ; valid loss = 0.6012, valid acc = 31539/34362
# train max item =  0.9973 , valid max item =  0.9981
# epoch 99 : train loss = 0.3898, train acc = 102673/105320 ; valid loss = 0.6016, valid acc = 31784/34362
# train max item =  0.9985 , valid max item =  0.9984
# epoch 100 : train loss = 0.3918, train acc = 102495/105320 ; valid loss = 0.58, valid acc = 31628/34362
# Epoch [100/250] : Train Loss : 0.3918, Valid Loss : 0.58
# train max item =  0.999 , valid max item =  0.9997
# epoch 101 : train loss = 0.397, train acc = 102479/105320 ; valid loss = 0.6039, valid acc = 31117/34362
# train max item =  0.9987 , valid max item =  0.9997
# epoch 102 : train loss = 0.3971, train acc = 102446/105320 ; valid loss = 0.5996, valid acc = 31010/34362
# train max item =  0.9991 , valid max item =  0.9991
# epoch 103 : train loss = 0.395, train acc = 102482/105320 ; valid loss = 0.5885, valid acc = 31356/34362
# train max item =  0.9994 , valid max item =  0.9995
# epoch 104 : train loss = 0.3928, train acc = 102629/105320 ; valid loss = 0.5726, valid acc = 31834/34362
# train max item =  0.9985 , valid max item =  0.9988
# epoch 105 : train loss = 0.3923, train acc = 102705/105320 ; valid loss = 0.5862, valid acc = 31017/34362
# train max item =  0.9983 , valid max item =  0.9995
# epoch 106 : train loss = 0.3914, train acc = 102666/105320 ; valid loss = 0.592, valid acc = 31065/34362
# train max item =  0.9985 , valid max item =  0.9989
# epoch 107 : train loss = 0.392, train acc = 102594/105320 ; valid loss = 0.5993, valid acc = 31581/34362
# train max item =  0.9991 , valid max item =  0.9981
# epoch 108 : train loss = 0.3935, train acc = 102501/105320 ; valid loss = 0.5671, valid acc = 31669/34362
# train max item =  0.9994 , valid max item =  0.9995
# epoch 109 : train loss = 0.3966, train acc = 102605/105320 ; valid loss = 0.5801, valid acc = 31423/34362
# train max item =  0.9997 , valid max item =  0.9987
# epoch 110 : train loss = 0.3929, train acc = 102555/105320 ; valid loss = 0.5927, valid acc = 31997/34362
# Epoch [110/250] : Train Loss : 0.3929, Valid Loss : 0.5927
# train max item =  0.9981 , valid max item =  0.9995
# epoch 111 : train loss = 0.3946, train acc = 102524/105320 ; valid loss = 0.6228, valid acc = 31167/34362
# train max item =  0.9986 , valid max item =  0.9968
# epoch 112 : train loss = 0.4046, train acc = 102329/105320 ; valid loss = 0.5502, valid acc = 31703/34362
# train max item =  0.999 , valid max item =  0.9965
# epoch 113 : train loss = 0.4111, train acc = 102354/105320 ; valid loss = 0.5503, valid acc = 31293/34362
# train max item =  0.9977 , valid max item =  0.9994
# epoch 114 : train loss = 0.403, train acc = 102482/105320 ; valid loss = 0.5907, valid acc = 30793/34362
# train max item =  0.9967 , valid max item =  0.9984
# epoch 115 : train loss = 0.4025, train acc = 102540/105320 ; valid loss = 0.6004, valid acc = 30809/34362
# Model is not improving, early stop at epoch 115.

# %% [markdown]
# #### Loss Curve

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(12,4))
ax1.set_title("bidirectional GRU Loss")
ax1.set_xlabel("epoch")
ax1.set_ylabel("loss")
ax1.plot(gru_train_loss_list, label="train loss")
ax1.plot(gru_valid_loss_list, label="valid loss")
ax1.legend()
ax2.set_title("bidirectional GRU Acc")
ax2.set_xlabel("epoch")
ax2.set_ylabel("acc")
ax2.plot(gru_train_acc_list, label="train acc")
ax2.plot(gru_valid_acc_list, label="valid acc")
ax2.legend()

# %% [markdown]
# #### ROC & PRC

# %%
bi_gru = bi_GRU(hidden_size=128, num_layers=1)
bi_gru.load_state_dict(torch.load(gru_model_path))
bi_gru.eval().to(device)
gru_train_loss, gru_train_proba = 0, []
gru_valid_loss, gru_valid_proba = 0, []
gru_test_loss, gru_test_proba = 0, []
with torch.no_grad():
    for x, y in tqdm(train_loader):
        x, y = x.float().to(device), y.float().to(device)
        output = bi_gru(x)
        loss = criterion(output, y)
        gru_train_loss += loss.detach().item()
        gru_train_proba += output.tolist()
    gru_train_proba = torch.sigmoid(torch.Tensor(gru_train_proba))
    gru_train_pred = [1 if prob >= 0.5 else 0 for prob in gru_train_proba]
    gru_train_loss = gru_train_loss/len(train_loader)
    print(f"train loss : {gru_train_loss}")
    for x, y in tqdm(valid_loader):
        x, y = x.float().to(device), y.float().to(device)
        output = bi_gru(x)
        loss = criterion(output, y)
        gru_valid_loss += loss.detach().item()
        gru_valid_proba += output.tolist()
    gru_valid_proba = torch.sigmoid(torch.Tensor(gru_valid_proba))
    gru_valid_pred = [1 if prob >= 0.5 else 0 for prob in gru_valid_proba]
    gru_valid_loss = gru_valid_loss/len(valid_loader)
    print(f"valid loss : {gru_valid_loss}")
    for x, y in tqdm(test_loader):
        x, y = x.float().to(device), y.float().to(device)
        output = bi_gru(x)
        loss = criterion(output, y)
        gru_test_loss += loss.detach().item()
        gru_test_proba += output.tolist()
    gru_test_proba = torch.sigmoid(torch.Tensor(gru_test_proba))
    gru_test_pred = [1 if prob >= 0.5 else 0 for prob in gru_test_proba]
    gru_test_loss = gru_test_loss/len(test_loader)
    print(f"test loss : {gru_test_loss}")
# Out:
# 100%|██████████| 103/103 [00:01<00:00, 84.41it/s]
# train loss : 0.40115904931015184
# 100%|██████████| 34/34 [00:00<00:00, 102.41it/s]
# valid loss : 0.6004267212222604
# 100%|██████████| 11/11 [00:00<00:00, 110.19it/s]
# test loss : 0.6048533130775798

# %%
plot_curve_(train_dataset.y, np.array(gru_train_proba), "bi-GRU on train set")

# %%
plot_curve_(valid_dataset.y, np.array(gru_valid_proba), "bi-GRU on valid set")

# %%
plot_curve_(test_dataset.y, np.array(gru_test_proba), "bi-GRU on test set")

# %%
plot_confusion_matrix(test_dataset.y, gru_test_pred, "bidirectional GRU")

# %% [markdown]
# ### Q6 : Transformer

# %%
transformer_model_path = "./models/transformer.ckpt"

# %%
class Transformer(nn.Module):
    def __init__(self):
        super(Transformer, self).__init__()
        self.transformer_encoder = nn.TransformerEncoderLayer(d_model=27, nhead=3, batch_first=True)
        self.fc = nn.Linear(11*27, 1)
    def forward(self, x):
        out = self.transformer_encoder(x)
        out = out.view(-1, 11*27)
        out = self.fc(out).view(-1)
        # out = torch.sigmoid(out)
        return out

# %%
# criterion = nn.BCELoss()
criterion = nn.BCEWithLogitsLoss(pos_weight=torch.Tensor([20]).to(device))   # use pos_weight to amplify the loss of False Negative
transformer = Transformer()
# optimizer = torch.optim.SGD(transformer.parameters(), lr=lr, momentum=0.9, nesterov=True)
# optimizer = torch.optim.SGD(transformer.parameters(), lr=lr, momentum=0)
optimizer = torch.optim.Adam(transformer.parameters(), lr=lr, weight_decay=0)
transformer.train().to(device)
transformer_train_loss_list, transformer_valid_loss_list = [], []
transformer_train_acc_list, transformer_valid_acc_list = [], []
lowest_loss, early_stop_count = float("inf"), 0
for epoch in range(n_epoch):
    train_max_, valid_max_ = 0, 0
    train_correct, valid_correct = 0, 0
    train_loss, valid_loss = 0, 0
    for x, y in train_loader:
        optimizer.zero_grad()
        x, y = x.float().to(device), y.float().to(device)
        output = transformer(x)

        train_max_item = max(torch.sigmoid(output))
        # train_max_item = max(output)
        train_max_ = max(train_max_item, train_max_)
        
        loss = criterion(output, y)
        loss.backward()
        optimizer.step()
        transformer_train_pred = [0 if i < 0.5 else 1 for i in output]
        train_loss += loss.detach().item()
        train_correct += sum(torch.Tensor(transformer_train_pred)==y.cpu().detach()).item()
    train_loss = train_loss/len(train_loader)
    transformer_train_loss_list.append(train_loss)
    train_acc = train_correct/len(train_dataset)
    transformer_train_acc_list.append(train_acc)
    
    with torch.no_grad():
        for x, y in valid_loader:
            x, y = x.float().to(device), y.float().to(device)
            output = transformer(x)
            
            valid_max_item = max(torch.sigmoid(output))
            # valid_max_item = max(output)
            valid_max_ = max(valid_max_item, valid_max_)

            loss = criterion(output, y)
            transformer_valid_pred = [0 if i < 0.5 else 1 for i in output]
            valid_loss += loss.detach().item()
            valid_correct += sum(torch.Tensor(transformer_valid_pred)==y.cpu().detach()).item()
        valid_loss = valid_loss/len(valid_loader)
        transformer_valid_loss_list.append(valid_loss)
        valid_acc = valid_correct/len(valid_dataset)
        transformer_valid_acc_list.append(valid_acc)

        print("train max item = ", round(train_max_.item(), 4), ", valid max item = ", round(valid_max_.item(), 4))

        torch.save(transformer.state_dict(), transformer_model_path)

        print(f"epoch {epoch+1} : train loss = {round(train_loss, 4)}, train acc = {train_correct}/{len(train_dataset)} ; valid loss = {round(valid_loss, 4)}, valid acc = {valid_correct}/{len(valid_dataset)}")
        if valid_loss < lowest_loss:
            lowest_loss = valid_loss
            early_stop_count = 0
            # torch.save(transformer.state_dict(), transformer_model_path)
            # print(f"Save model at epoch {epoch+1} with valid loss = {round(valid_loss, 4)}")
        else:
            early_stop_count += 1
        
        if early_stop_count >= early_stop:
            print(f'Model is not improving, early stop at epoch {epoch+1}.')
            break

    if (epoch+1)%10 == 0:
        print(f'Epoch [{epoch+1}/{n_epoch}] : Train Loss : {round(train_loss, 4)}, Valid Loss : {round(valid_loss, 4)}')
# Out:
# train max item =  0.9348 , valid max item =  0.8966
# epoch 1 : train loss = 0.5271, train acc = 101703/105320 ; valid loss = 0.45, valid acc = 31166/34362
# train max item =  0.9162 , valid max item =  0.9177
# epoch 2 : train loss = 0.4681, train acc = 102074/105320 ; valid loss = 0.4834, valid acc = 31078/34362
# train max item =  0.9246 , valid max item =  0.9137
# epoch 3 : train loss = 0.4587, train acc = 102337/105320 ; valid loss = 0.5538, valid acc = 30072/34362
# train max item =  0.9016 , valid max item =  0.9237
# epoch 4 : train loss = 0.4567, train acc = 102356/105320 ; valid loss = 0.5619, valid acc = 29716/34362
# train max item =  0.9271 , valid max item =  0.9569
# epoch 5 : train loss = 0.4515, train acc = 102155/105320 ; valid loss = 0.5903, valid acc = 29096/34362
# train max item =  0.9309 , valid max item =  0.9545
# epoch 6 : train loss = 0.4485, train acc = 102307/105320 ; valid loss = 0.5792, valid acc = 29157/34362
# train max item =  0.9548 , valid max item =  0.9641
# epoch 7 : train loss = 0.4487, train acc = 102204/105320 ; valid loss = 0.6055, valid acc = 28625/34362
# train max item =  0.9649 , valid max item =  0.9738
# epoch 8 : train loss = 0.4477, train acc = 102383/105320 ; valid loss = 0.6215, valid acc = 28382/34362
# train max item =  0.9747 , valid max item =  0.9686
# epoch 9 : train loss = 0.4475, train acc = 102258/105320 ; valid loss = 0.6118, valid acc = 28282/34362
# train max item =  0.9449 , valid max item =  0.9761
# epoch 10 : train loss = 0.4437, train acc = 102437/105320 ; valid loss = 0.6272, valid acc = 28092/34362
# Epoch [10/250] : Train Loss : 0.4437, Valid Loss : 0.6272
# train max item =  0.9461 , valid max item =  0.9846
# epoch 11 : train loss = 0.4426, train acc = 102337/105320 ; valid loss = 0.6267, valid acc = 28344/34362
# train max item =  0.9552 , valid max item =  0.9775
# epoch 12 : train loss = 0.4403, train acc = 102462/105320 ; valid loss = 0.6376, valid acc = 28089/34362
# train max item =  0.969 , valid max item =  0.9882
# epoch 13 : train loss = 0.4403, train acc = 102447/105320 ; valid loss = 0.6289, valid acc = 28470/34362
# train max item =  0.9621 , valid max item =  0.9892
# epoch 14 : train loss = 0.4405, train acc = 102395/105320 ; valid loss = 0.6264, valid acc = 28280/34362
# train max item =  0.951 , valid max item =  0.9941
# epoch 15 : train loss = 0.4391, train acc = 102429/105320 ; valid loss = 0.6251, valid acc = 28626/34362
# train max item =  0.9559 , valid max item =  0.9792
# epoch 16 : train loss = 0.4389, train acc = 102306/105320 ; valid loss = 0.565, valid acc = 29879/34362
# train max item =  0.9705 , valid max item =  0.9818
# epoch 17 : train loss = 0.4368, train acc = 102418/105320 ; valid loss = 0.5725, valid acc = 29955/34362
# train max item =  0.9765 , valid max item =  0.986
# epoch 18 : train loss = 0.4362, train acc = 102414/105320 ; valid loss = 0.5976, valid acc = 29214/34362
# train max item =  0.9634 , valid max item =  0.9879
# epoch 19 : train loss = 0.434, train acc = 102563/105320 ; valid loss = 0.6112, valid acc = 28841/34362
# train max item =  0.9673 , valid max item =  0.9833
# epoch 20 : train loss = 0.4326, train acc = 102522/105320 ; valid loss = 0.579, valid acc = 29528/34362
# Epoch [20/250] : Train Loss : 0.4326, Valid Loss : 0.579
# train max item =  0.9597 , valid max item =  0.9843
# epoch 21 : train loss = 0.4348, train acc = 102371/105320 ; valid loss = 0.5855, valid acc = 29251/34362
# train max item =  0.9659 , valid max item =  0.9792
# epoch 22 : train loss = 0.427, train acc = 102506/105320 ; valid loss = 0.5833, valid acc = 29665/34362
# train max item =  0.9869 , valid max item =  0.9915
# epoch 23 : train loss = 0.4304, train acc = 102483/105320 ; valid loss = 0.6255, valid acc = 28519/34362
# train max item =  0.9781 , valid max item =  0.9853
# epoch 24 : train loss = 0.43, train acc = 102517/105320 ; valid loss = 0.5754, valid acc = 29443/34362
# train max item =  0.973 , valid max item =  0.983
# epoch 25 : train loss = 0.4261, train acc = 102561/105320 ; valid loss = 0.5677, valid acc = 29702/34362
# train max item =  0.9585 , valid max item =  0.9877
# epoch 26 : train loss = 0.4284, train acc = 102428/105320 ; valid loss = 0.5463, valid acc = 30361/34362
# train max item =  0.9832 , valid max item =  0.9891
# epoch 27 : train loss = 0.4281, train acc = 102542/105320 ; valid loss = 0.6042, valid acc = 29208/34362
# train max item =  0.9878 , valid max item =  0.9918
# epoch 28 : train loss = 0.4266, train acc = 102549/105320 ; valid loss = 0.6083, valid acc = 28915/34362
# train max item =  0.9798 , valid max item =  0.9932
# epoch 29 : train loss = 0.426, train acc = 102425/105320 ; valid loss = 0.5883, valid acc = 29697/34362
# train max item =  0.9846 , valid max item =  0.9918
# epoch 30 : train loss = 0.4248, train acc = 102450/105320 ; valid loss = 0.5884, valid acc = 29592/34362
# Epoch [30/250] : Train Loss : 0.4248, Valid Loss : 0.5884
# train max item =  0.9784 , valid max item =  0.9911
# epoch 31 : train loss = 0.4246, train acc = 102552/105320 ; valid loss = 0.5739, valid acc = 29962/34362
# train max item =  0.9875 , valid max item =  0.9961
# epoch 32 : train loss = 0.4256, train acc = 102391/105320 ; valid loss = 0.5905, valid acc = 29492/34362
# train max item =  0.9732 , valid max item =  0.9933
# epoch 33 : train loss = 0.4236, train acc = 102510/105320 ; valid loss = 0.6041, valid acc = 29404/34362
# train max item =  0.9748 , valid max item =  0.9942
# epoch 34 : train loss = 0.4235, train acc = 102439/105320 ; valid loss = 0.5773, valid acc = 30028/34362
# train max item =  0.9872 , valid max item =  0.9965
# epoch 35 : train loss = 0.4181, train acc = 102569/105320 ; valid loss = 0.5733, valid acc = 30236/34362
# train max item =  0.9833 , valid max item =  0.9952
# epoch 36 : train loss = 0.4216, train acc = 102366/105320 ; valid loss = 0.5836, valid acc = 29998/34362
# train max item =  0.9888 , valid max item =  0.9968
# epoch 37 : train loss = 0.4206, train acc = 102430/105320 ; valid loss = 0.5893, valid acc = 29795/34362
# train max item =  0.9867 , valid max item =  0.9964
# epoch 38 : train loss = 0.4218, train acc = 102531/105320 ; valid loss = 0.5543, valid acc = 30427/34362
# train max item =  0.992 , valid max item =  0.9973
# epoch 39 : train loss = 0.4205, train acc = 102552/105320 ; valid loss = 0.5839, valid acc = 30299/34362
# train max item =  0.9817 , valid max item =  0.9958
# epoch 40 : train loss = 0.4198, train acc = 102478/105320 ; valid loss = 0.5542, valid acc = 30836/34362
# Epoch [40/250] : Train Loss : 0.4198, Valid Loss : 0.5542
# train max item =  0.9936 , valid max item =  0.9952
# epoch 41 : train loss = 0.4182, train acc = 102477/105320 ; valid loss = 0.5779, valid acc = 30382/34362
# train max item =  0.9903 , valid max item =  0.9919
# epoch 42 : train loss = 0.4173, train acc = 102386/105320 ; valid loss = 0.5759, valid acc = 30150/34362
# train max item =  0.983 , valid max item =  0.9974
# epoch 43 : train loss = 0.4154, train acc = 102536/105320 ; valid loss = 0.573, valid acc = 30449/34362
# train max item =  0.9799 , valid max item =  0.9944
# epoch 44 : train loss = 0.4179, train acc = 102519/105320 ; valid loss = 0.5783, valid acc = 30229/34362
# train max item =  0.9861 , valid max item =  0.9953
# epoch 45 : train loss = 0.4151, train acc = 102568/105320 ; valid loss = 0.5592, valid acc = 30796/34362
# train max item =  0.9925 , valid max item =  0.9919
# epoch 46 : train loss = 0.4182, train acc = 102570/105320 ; valid loss = 0.5629, valid acc = 30806/34362
# train max item =  0.9971 , valid max item =  0.9979
# epoch 47 : train loss = 0.4132, train acc = 102585/105320 ; valid loss = 0.5999, valid acc = 29932/34362
# train max item =  0.9884 , valid max item =  0.9911
# epoch 48 : train loss = 0.4138, train acc = 102490/105320 ; valid loss = 0.5659, valid acc = 30533/34362
# train max item =  0.9844 , valid max item =  0.9983
# epoch 49 : train loss = 0.4123, train acc = 102546/105320 ; valid loss = 0.5532, valid acc = 31054/34362
# train max item =  0.9877 , valid max item =  0.9935
# epoch 50 : train loss = 0.4133, train acc = 102433/105320 ; valid loss = 0.5665, valid acc = 30741/34362
# Epoch [50/250] : Train Loss : 0.4133, Valid Loss : 0.5665
# train max item =  0.994 , valid max item =  0.9958
# epoch 51 : train loss = 0.4102, train acc = 102632/105320 ; valid loss = 0.5611, valid acc = 30554/34362
# Model is not improving, early stop at epoch 51.

# %% [markdown]
# #### Loss Curve

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(12,4))
ax1.set_title("Transformer Loss")
ax1.set_xlabel("epoch")
ax1.set_ylabel("loss")
ax1.plot(transformer_train_loss_list, label="train loss")
ax1.plot(transformer_valid_loss_list, label="valid loss")
ax1.legend()
ax2.set_title("Transformer Acc")
ax2.set_xlabel("epoch")
ax2.set_ylabel("acc")
ax2.plot(transformer_train_acc_list, label="train acc")
ax2.plot(transformer_valid_acc_list, label="valid acc")
ax2.legend()

# %% [markdown]
# #### ROC & PRC

# %%
transformer = Transformer()
transformer.load_state_dict(torch.load(transformer_model_path))
transformer.eval().to(device)
transformer_train_loss, transformer_train_proba = 0, []
transformer_valid_loss, transformer_valid_proba = 0, []
transformer_test_loss, transformer_test_proba = 0, []
with torch.no_grad():
    for x, y in tqdm(train_loader):
        x, y = x.float().to(device), y.float().to(device)
        output = transformer(x)
        loss = criterion(output, y)
        transformer_train_loss += loss.detach().item()
        transformer_train_proba += output.tolist()
    transformer_train_proba = torch.sigmoid(torch.Tensor(transformer_train_proba))
    transformer_train_pred = [1 if prob >= 0.5 else 0 for prob in transformer_train_proba]
    transformer_train_loss = transformer_train_loss/len(train_loader)
    print(f"train loss : {transformer_train_loss}")
    for x, y in tqdm(valid_loader):
        x, y = x.float().to(device), y.float().to(device)
        output = transformer(x)
        loss = criterion(output, y)
        transformer_valid_loss += loss.detach().item()
        transformer_valid_proba += output.tolist()
    transformer_valid_proba = torch.sigmoid(torch.Tensor(transformer_valid_proba))
    transformer_valid_pred = [1 if prob >= 0.5 else 0 for prob in transformer_valid_proba]
    transformer_valid_loss = transformer_valid_loss/len(valid_loader)
    print(f"valid loss : {transformer_valid_loss}")
    for x, y in tqdm(test_loader):
        x, y = x.float().to(device), y.float().to(device)
        output = transformer(x)
        loss = criterion(output, y)
        transformer_test_loss += loss.detach().item()
        transformer_test_proba += output.tolist()
    transformer_test_proba = torch.sigmoid(torch.Tensor(transformer_test_proba))
    transformer_test_pred = [1 if prob >= 0.5 else 0 for prob in transformer_test_proba]
    transformer_test_loss = transformer_test_loss/len(test_loader)
    print(f"test loss : {transformer_test_loss}")
# Out:
# 100%|██████████| 103/103 [00:01<00:00, 57.00it/s]
# train loss : 0.3926610435241634
# 100%|██████████| 34/34 [00:00<00:00, 90.63it/s]
# valid loss : 0.5634117091403288
# 100%|██████████| 11/11 [00:00<00:00, 103.73it/s]
# test loss : 0.6046290858225389

# %%
plot_curve_(train_dataset.y, np.array(transformer_train_proba), "Transformer on train set")

# %%
plot_curve_(valid_dataset.y, np.array(transformer_valid_proba), "Transformer on valid set")

# %%
plot_curve_(test_dataset.y, np.array(transformer_test_proba), "Transformer on test set")

# %%
plot_confusion_matrix(test_dataset.y, transformer_test_pred, "Transformer")

# %% [markdown]
# ### Q8 : Ablation Study on sequence length

# %% [markdown]
# #### Model with last 3

# %%
class CTRPredictDataset_last3(Dataset):
    def __init__(self, data_df):
        self.x = torch.Tensor([np.array(history[-3:] + [target]) for (history, target) in zip(data_df['click_seq_10_onehot'].values, data_df['target_news_onehot'].values)])
        self.y = torch.Tensor(data_df['y'].values)
        self.pos_num = sum(self.y)
    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]
    def __len__(self):
        return len(self.x)

# %%
train_dataset_last3 = CTRPredictDataset_last3(train_df)
valid_dataset_last3 = CTRPredictDataset_last3(valid_df)
test_dataset_last3 = CTRPredictDataset_last3(test_df)

train_loader_last3 = DataLoader(train_dataset_last3, batch_size=batch_size, shuffle=False, pin_memory=True)
valid_loader_last3 = DataLoader(valid_dataset_last3, batch_size=batch_size, shuffle=False, pin_memory=True)
test_loader_last3 = DataLoader(test_dataset_last3, batch_size=batch_size, shuffle=False, pin_memory=True)

# %%
class bi_LSTM(nn.Module):
    def __init__(self, hidden_size=128, num_layers=1):
        super(bi_LSTM, self).__init__()
        self.lstm = nn.LSTM(input_size=27, hidden_size=hidden_size, num_layers=num_layers, batch_first=True, bidirectional=True)
        self.fc = nn.Linear(hidden_size * 2, 1)
    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc(out[:,-1,:]).view(-1)
        # out = torch.sigmoid(out) 
        return out

# %% [markdown]
# ##### Training

# %%
lstm_last3_model_path = "./models/lstm_last3.ckpt"

# %%
# criterion = nn.BCELoss()
criterion = nn.BCEWithLogitsLoss(pos_weight=torch.Tensor([20]).to(device))   # use pos_weight to amplify the loss of False Negative
bi_lstm_last3 = bi_LSTM(hidden_size=128, num_layers=1)
# optimizer = torch.optim.SGD(bi_lstm_last3.parameters(), lr=lr, momentum=0.9, nesterov=True)
# optimizer = torch.optim.SGD(bi_lstm_last3.parameters(), lr=lr, momentum=0)
optimizer = torch.optim.Adam(bi_lstm_last3.parameters(), lr=lr, weight_decay=0)
bi_lstm_last3.train().to(device)
lstm_last3_train_loss_list, lstm_last3_valid_loss_list = [], []
lstm_last3_train_acc_list, lstm_last3_valid_acc_list = [], []
lowest_loss, early_stop_count = float("inf"), 0
for epoch in range(n_epoch):
    train_max_, valid_max_ = 0, 0
    train_correct, valid_correct = 0, 0
    train_loss, valid_loss = 0, 0
    for x, y in train_loader_last3:
        optimizer.zero_grad()
        x, y = x.float().to(device), y.float().to(device)
        output = bi_lstm_last3(x)

        train_max_item = max(torch.sigmoid(output))
        # train_max_item = max(output)
        train_max_ = max(train_max_item, train_max_)
        
        loss = criterion(output, y)
        loss.backward()
        optimizer.step()
        lstm_last3_train_pred = [0 if i < 0.5 else 1 for i in output]
        train_loss += loss.detach().item()
        train_correct += sum(torch.Tensor(lstm_last3_train_pred)==y.cpu().detach()).item()
    train_loss = train_loss/len(train_loader)
    lstm_last3_train_loss_list.append(train_loss)
    train_acc = train_correct/len(train_dataset)
    lstm_last3_train_acc_list.append(train_acc)
    
    with torch.no_grad():
        for x, y in valid_loader_last3:
            x, y = x.float().to(device), y.float().to(device)
            output = bi_lstm_last3(x)
            
            valid_max_item = max(torch.sigmoid(output))
            # valid_max_item = max(output)
            valid_max_ = max(valid_max_item, valid_max_)

            loss = criterion(output, y)
            lstm_last3_valid_pred = [0 if i < 0.5 else 1 for i in output]
            valid_loss += loss.detach().item()
            valid_correct += sum(torch.Tensor(lstm_last3_valid_pred)==y.cpu().detach()).item()
        valid_loss = valid_loss/len(valid_loader)
        lstm_last3_valid_loss_list.append(valid_loss)
        valid_acc = valid_correct/len(valid_dataset)
        lstm_last3_valid_acc_list.append(valid_acc)

        print("train max item = ", round(train_max_.item(), 4), ", valid max item = ", round(valid_max_.item(), 4))

        torch.save(bi_lstm_last3.state_dict(), lstm_last3_model_path)

        print(f"epoch {epoch+1} : train loss = {round(train_loss, 4)}, train acc = {train_correct}/{len(train_dataset)} ; valid loss = {round(valid_loss, 4)}, valid acc = {valid_correct}/{len(valid_dataset)}")
        if valid_loss < lowest_loss:
            lowest_loss = valid_loss
            early_stop_count = 0
            # torch.save(bi_lstm_last3.state_dict(), lstm_last3_model_path)
            # print(f"Save model at epoch {epoch+1} with valid loss = {round(valid_loss, 4)}")
        else:
            early_stop_count += 1
        
        if early_stop_count >= early_stop:
            print(f'Model is not improving, early stop at epoch {epoch+1}.')
            break

    if (epoch+1)%10 == 0:
        print(f'Epoch [{epoch+1}/{n_epoch}] : Train Loss : {round(train_loss, 4)}, Valid Loss : {round(valid_loss, 4)}')
# Out:
# train max item =  0.8013 , valid max item =  0.799
# epoch 1 : train loss = 0.4984, train acc = 102331/105320 ; valid loss = 0.5277, valid acc = 29091/34362
# train max item =  0.8016 , valid max item =  0.7735
# epoch 2 : train loss = 0.4617, train acc = 102871/105320 ; valid loss = 0.5105, valid acc = 29962/34362
# train max item =  0.7991 , valid max item =  0.7629
# epoch 3 : train loss = 0.4574, train acc = 102968/105320 ; valid loss = 0.5279, valid acc = 29980/34362
# train max item =  0.8001 , valid max item =  0.7889
# epoch 4 : train loss = 0.4562, train acc = 102973/105320 ; valid loss = 0.5233, valid acc = 30109/34362
# train max item =  0.8015 , valid max item =  0.8417
# epoch 5 : train loss = 0.4526, train acc = 102836/105320 ; valid loss = 0.523, valid acc = 30062/34362
# train max item =  0.8536 , valid max item =  0.8847
# epoch 6 : train loss = 0.4497, train acc = 102766/105320 ; valid loss = 0.5377, valid acc = 29791/34362
# train max item =  0.8844 , valid max item =  0.9082
# epoch 7 : train loss = 0.4477, train acc = 102801/105320 ; valid loss = 0.5443, valid acc = 29594/34362
# train max item =  0.9175 , valid max item =  0.9109
# epoch 8 : train loss = 0.4457, train acc = 102766/105320 ; valid loss = 0.5568, valid acc = 29333/34362
# train max item =  0.9339 , valid max item =  0.9099
# epoch 9 : train loss = 0.4431, train acc = 102762/105320 ; valid loss = 0.5628, valid acc = 29030/34362
# train max item =  0.9411 , valid max item =  0.9347
# epoch 10 : train loss = 0.4398, train acc = 102622/105320 ; valid loss = 0.5628, valid acc = 29162/34362
# Epoch [10/250] : Train Loss : 0.4398, Valid Loss : 0.5628
# train max item =  0.9462 , valid max item =  0.9329
# epoch 11 : train loss = 0.4365, train acc = 102588/105320 ; valid loss = 0.5627, valid acc = 29258/34362
# train max item =  0.9673 , valid max item =  0.95
# epoch 12 : train loss = 0.4327, train acc = 102565/105320 ; valid loss = 0.5486, valid acc = 29752/34362
# train max item =  0.9743 , valid max item =  0.9549
# epoch 13 : train loss = 0.427, train acc = 102419/105320 ; valid loss = 0.5413, valid acc = 29925/34362
# train max item =  0.9847 , valid max item =  0.9732
# epoch 14 : train loss = 0.4225, train acc = 102338/105320 ; valid loss = 0.5289, valid acc = 30351/34362
# train max item =  0.9813 , valid max item =  0.989
# epoch 15 : train loss = 0.4161, train acc = 102456/105320 ; valid loss = 0.5252, valid acc = 30617/34362
# train max item =  0.9902 , valid max item =  0.9864
# epoch 16 : train loss = 0.4103, train acc = 102628/105320 ; valid loss = 0.5285, valid acc = 31092/34362
# train max item =  0.9897 , valid max item =  0.9946
# epoch 17 : train loss = 0.4079, train acc = 102508/105320 ; valid loss = 0.549, valid acc = 30917/34362
# train max item =  0.9908 , valid max item =  0.9887
# epoch 18 : train loss = 0.4046, train acc = 102691/105320 ; valid loss = 0.5215, valid acc = 31231/34362
# train max item =  0.9899 , valid max item =  0.9906
# epoch 19 : train loss = 0.3978, train acc = 102782/105320 ; valid loss = 0.5157, valid acc = 31705/34362
# train max item =  0.995 , valid max item =  0.9948
# epoch 20 : train loss = 0.3913, train acc = 102951/105320 ; valid loss = 0.5144, valid acc = 31700/34362
# Epoch [20/250] : Train Loss : 0.3913, Valid Loss : 0.5144
# train max item =  0.9957 , valid max item =  0.9866
# epoch 21 : train loss = 0.3783, train acc = 103095/105320 ; valid loss = 0.5179, valid acc = 32218/34362
# train max item =  0.999 , valid max item =  0.9901
# epoch 22 : train loss = 0.3724, train acc = 103154/105320 ; valid loss = 0.5233, valid acc = 32143/34362
# train max item =  0.9978 , valid max item =  0.9956
# epoch 23 : train loss = 0.3705, train acc = 103088/105320 ; valid loss = 0.5114, valid acc = 32565/34362
# train max item =  0.9996 , valid max item =  0.9971
# epoch 24 : train loss = 0.3621, train acc = 103264/105320 ; valid loss = 0.5259, valid acc = 32646/34362
# train max item =  0.9996 , valid max item =  0.9959
# epoch 25 : train loss = 0.3571, train acc = 103258/105320 ; valid loss = 0.5351, valid acc = 32657/34362
# train max item =  0.9994 , valid max item =  0.9973
# epoch 26 : train loss = 0.3544, train acc = 103314/105320 ; valid loss = 0.5364, valid acc = 32812/34362
# train max item =  0.9996 , valid max item =  0.9967
# epoch 27 : train loss = 0.3487, train acc = 103364/105320 ; valid loss = 0.5538, valid acc = 32801/34362
# train max item =  0.9992 , valid max item =  0.9991
# epoch 28 : train loss = 0.3445, train acc = 103352/105320 ; valid loss = 0.58, valid acc = 32527/34362
# train max item =  0.9998 , valid max item =  0.9982
# epoch 29 : train loss = 0.3419, train acc = 103412/105320 ; valid loss = 0.5839, valid acc = 32651/34362
# train max item =  0.9994 , valid max item =  0.9996
# epoch 30 : train loss = 0.34, train acc = 103411/105320 ; valid loss = 0.5885, valid acc = 32699/34362
# Epoch [30/250] : Train Loss : 0.34, Valid Loss : 0.5885
# train max item =  0.9998 , valid max item =  0.9978
# epoch 31 : train loss = 0.3409, train acc = 103400/105320 ; valid loss = 0.5626, valid acc = 32476/34362
# train max item =  0.9999 , valid max item =  0.9979
# epoch 32 : train loss = 0.3351, train acc = 103411/105320 ; valid loss = 0.5938, valid acc = 32537/34362
# train max item =  0.9999 , valid max item =  0.9996
# epoch 33 : train loss = 0.3331, train acc = 103426/105320 ; valid loss = 0.6069, valid acc = 32416/34362
# train max item =  0.9998 , valid max item =  0.999
# epoch 34 : train loss = 0.3317, train acc = 103438/105320 ; valid loss = 0.5994, valid acc = 32466/34362
# train max item =  0.9999 , valid max item =  0.9993
# epoch 35 : train loss = 0.3292, train acc = 103464/105320 ; valid loss = 0.6068, valid acc = 32726/34362
# train max item =  0.9999 , valid max item =  0.9995
# epoch 36 : train loss = 0.3267, train acc = 103488/105320 ; valid loss = 0.6181, valid acc = 32549/34362
# train max item =  0.9999 , valid max item =  0.9995
# epoch 37 : train loss = 0.3253, train acc = 103437/105320 ; valid loss = 0.6439, valid acc = 32746/34362
# train max item =  0.9999 , valid max item =  0.9985
# epoch 38 : train loss = 0.3235, train acc = 103487/105320 ; valid loss = 0.6529, valid acc = 32983/34362
# train max item =  0.9999 , valid max item =  0.9991
# epoch 39 : train loss = 0.3225, train acc = 103443/105320 ; valid loss = 0.647, valid acc = 33044/34362
# train max item =  0.9999 , valid max item =  0.9995
# epoch 40 : train loss = 0.3221, train acc = 103475/105320 ; valid loss = 0.654, valid acc = 32814/34362
# Epoch [40/250] : Train Loss : 0.3221, Valid Loss : 0.654
# train max item =  0.9999 , valid max item =  0.9989
# epoch 41 : train loss = 0.3238, train acc = 103456/105320 ; valid loss = 0.6547, valid acc = 32559/34362
# train max item =  0.9999 , valid max item =  0.9995
# epoch 42 : train loss = 0.3212, train acc = 103433/105320 ; valid loss = 0.6493, valid acc = 32703/34362
# train max item =  1.0 , valid max item =  0.9995
# epoch 43 : train loss = 0.3216, train acc = 103440/105320 ; valid loss = 0.6731, valid acc = 32876/34362
# train max item =  0.9998 , valid max item =  0.9992
# epoch 44 : train loss = 0.3235, train acc = 103427/105320 ; valid loss = 0.6376, valid acc = 32712/34362
# train max item =  0.9999 , valid max item =  0.9995
# epoch 45 : train loss = 0.3224, train acc = 103465/105320 ; valid loss = 0.6424, valid acc = 32704/34362
# train max item =  0.9999 , valid max item =  0.9997
# epoch 46 : train loss = 0.3198, train acc = 103442/105320 ; valid loss = 0.6619, valid acc = 32672/34362
# train max item =  0.9999 , valid max item =  0.9997
# epoch 47 : train loss = 0.3188, train acc = 103460/105320 ; valid loss = 0.6669, valid acc = 32786/34362
# train max item =  0.9999 , valid max item =  0.9992
# epoch 48 : train loss = 0.317, train acc = 103426/105320 ; valid loss = 0.6808, valid acc = 32684/34362
# train max item =  0.9999 , valid max item =  0.9997
# epoch 49 : train loss = 0.3172, train acc = 103425/105320 ; valid loss = 0.6868, valid acc = 32757/34362
# train max item =  0.9999 , valid max item =  0.9994
# epoch 50 : train loss = 0.3161, train acc = 103422/105320 ; valid loss = 0.6911, valid acc = 32774/34362
# Epoch [50/250] : Train Loss : 0.3161, Valid Loss : 0.6911
# train max item =  0.9999 , valid max item =  0.9997
# epoch 51 : train loss = 0.3151, train acc = 103415/105320 ; valid loss = 0.6966, valid acc = 32735/34362
# train max item =  0.9999 , valid max item =  0.9997
# epoch 52 : train loss = 0.3142, train acc = 103471/105320 ; valid loss = 0.7016, valid acc = 32635/34362
# Model is not improving, early stop at epoch 52.

# %% [markdown]
# ##### Loss Curve

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(12,4))
ax1.set_title("bidirectional LSTM (with last 3) Loss")
ax1.set_xlabel("epoch")
ax1.set_ylabel("loss")
ax1.plot(lstm_last3_train_loss_list, label="train loss")
ax1.plot(lstm_last3_valid_loss_list, label="valid loss")
ax1.legend()
ax2.set_title("bidirectional LSTM (with last 3) Acc")
ax2.set_xlabel("epoch")
ax2.set_ylabel("acc")
ax2.plot(lstm_last3_train_acc_list, label="train acc")
ax2.plot(lstm_last3_valid_acc_list, label="valid acc")
ax2.legend()

# %% [markdown]
# ##### ROC & PRC

# %%
bi_lstm_last3 = bi_LSTM(hidden_size=128, num_layers=1)
bi_lstm_last3.load_state_dict(torch.load(lstm_last3_model_path))
bi_lstm_last3.eval().to(device)
lstm_last3_train_loss, lstm_last3_train_proba = 0, []
lstm_last3_valid_loss, lstm_last3_valid_proba = 0, []
lstm_last3_test_loss, lstm_last3_test_proba = 0, []
with torch.no_grad():
    for x, y in tqdm(train_loader_last3):
        x, y = x.float().to(device), y.float().to(device)
        output = bi_lstm_last3(x)
        loss = criterion(output, y)
        lstm_last3_train_loss += loss.detach().item()
        lstm_last3_train_proba += output.tolist()
    lstm_last3_train_proba = torch.sigmoid(torch.Tensor(lstm_last3_train_proba))
    lstm_last3_train_pred = [1 if prob >= 0.5 else 0 for prob in lstm_last3_train_proba]
    lstm_last3_train_loss = lstm_last3_train_loss/len(train_loader_last3)
    print(f"train loss : {lstm_last3_train_loss}")
    for x, y in tqdm(valid_loader_last3):
        x, y = x.float().to(device), y.float().to(device)
        output = bi_lstm_last3(x)
        loss = criterion(output, y)
        lstm_last3_valid_loss += loss.detach().item()
        lstm_last3_valid_proba += output.tolist()
    lstm_last3_valid_proba = torch.sigmoid(torch.Tensor(lstm_last3_valid_proba))
    lstm_last3_valid_pred = [1 if prob >= 0.5 else 0 for prob in lstm_last3_valid_proba]
    lstm_last3_valid_loss = lstm_last3_valid_loss/len(valid_loader_last3)
    print(f"valid loss : {lstm_last3_valid_loss}")
    for x, y in tqdm(test_loader_last3):
        x, y = x.float().to(device), y.float().to(device)
        output = bi_lstm_last3(x)
        loss = criterion(output, y)
        lstm_last3_test_loss += loss.detach().item()
        lstm_last3_test_proba += output.tolist()
    lstm_last3_test_proba = torch.sigmoid(torch.Tensor(lstm_last3_test_proba))
    lstm_last3_test_pred = [1 if prob >= 0.5 else 0 for prob in lstm_last3_test_proba]
    lstm_last3_test_loss = lstm_last3_test_loss/len(test_loader_last3)
    print(f"test loss : {lstm_last3_test_loss}")
# Out:
# 100%|██████████| 103/103 [00:00<00:00, 137.79it/s]
# train loss : 0.3063975247075257
# 100%|██████████| 34/34 [00:00<00:00, 143.83it/s]
# valid loss : 0.7016337154542699
# 100%|██████████| 11/11 [00:00<00:00, 146.32it/s]
# test loss : 0.7143604945052754

# %%
plot_curve_(train_dataset.y, np.array(lstm_last3_train_proba), "bi-LSTM (last 3) on train set")

# %%
plot_curve_(valid_dataset.y, np.array(lstm_last3_valid_proba), "bi-LSTM (last 3) on valid set")

# %%
plot_curve_(test_dataset.y, np.array(lstm_last3_test_proba), "bi-LSTM (last 3) on test set")

# %%
plot_confusion_matrix(test_dataset.y, lstm_last3_test_pred, "bi-LSTM (last 3)")

# %% [markdown]
# #### Model with last 5

# %%
class CTRPredictDataset_last5(Dataset):
    def __init__(self, data_df):
        self.x = torch.Tensor([np.array(history[-5:] + [target]) for (history, target) in zip(data_df['click_seq_10_onehot'].values, data_df['target_news_onehot'].values)])
        self.y = torch.Tensor(data_df['y'].values)
        self.pos_num = sum(self.y)
    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]
    def __len__(self):
        return len(self.x)

# %%
train_dataset_last5 = CTRPredictDataset_last5(train_df)
valid_dataset_last5 = CTRPredictDataset_last5(valid_df)
test_dataset_last5 = CTRPredictDataset_last5(test_df)

train_loader_last5 = DataLoader(train_dataset_last5, batch_size=batch_size, shuffle=False, pin_memory=True)
valid_loader_last5 = DataLoader(valid_dataset_last5, batch_size=batch_size, shuffle=False, pin_memory=True)
test_loader_last5 = DataLoader(test_dataset_last5, batch_size=batch_size, shuffle=False, pin_memory=True)

# %%
class bi_LSTM(nn.Module):
    def __init__(self, hidden_size=128, num_layers=1):
        super(bi_LSTM, self).__init__()
        self.lstm = nn.LSTM(input_size=27, hidden_size=hidden_size, num_layers=num_layers, batch_first=True, bidirectional=True)
        self.fc = nn.Linear(hidden_size * 2, 1)
    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc(out[:,-1,:]).view(-1)
        # out = torch.sigmoid(out) 
        return out

# %% [markdown]
# ##### Training

# %%
lstm_last5_model_path = "./models/lstm_last5.ckpt"

# %%
# criterion = nn.BCELoss()
criterion = nn.BCEWithLogitsLoss(pos_weight=torch.Tensor([20]).to(device))   # use pos_weight to amplify the loss of False Negative
bi_lstm_last5 = bi_LSTM(hidden_size=128, num_layers=1)
# optimizer = torch.optim.SGD(bi_lstm_last5.parameters(), lr=lr, momentum=0.9, nesterov=True)
# optimizer = torch.optim.SGD(bi_lstm_last5.parameters(), lr=lr, momentum=0)
optimizer = torch.optim.Adam(bi_lstm_last5.parameters(), lr=lr, weight_decay=0)
bi_lstm_last5.train().to(device)
lstm_last5_train_loss_list, lstm_last5_valid_loss_list = [], []
lstm_last5_train_acc_list, lstm_last5_valid_acc_list = [], []
lowest_loss, early_stop_count = float("inf"), 0
for epoch in range(n_epoch):
    train_max_, valid_max_ = 0, 0
    train_correct, valid_correct = 0, 0
    train_loss, valid_loss = 0, 0
    for x, y in train_loader_last5:
        optimizer.zero_grad()
        x, y = x.float().to(device), y.float().to(device)
        output = bi_lstm_last5(x)

        train_max_item = max(torch.sigmoid(output))
        # train_max_item = max(output)
        train_max_ = max(train_max_item, train_max_)
        
        loss = criterion(output, y)
        loss.backward()
        optimizer.step()
        lstm_last5_train_pred = [0 if i < 0.5 else 1 for i in output]
        train_loss += loss.detach().item()
        train_correct += sum(torch.Tensor(lstm_last5_train_pred)==y.cpu().detach()).item()
    train_loss = train_loss/len(train_loader)
    lstm_last5_train_loss_list.append(train_loss)
    train_acc = train_correct/len(train_dataset)
    lstm_last5_train_acc_list.append(train_acc)
    
    with torch.no_grad():
        for x, y in valid_loader_last5:
            x, y = x.float().to(device), y.float().to(device)
            output = bi_lstm_last5(x)
            
            valid_max_item = max(torch.sigmoid(output))
            # valid_max_item = max(output)
            valid_max_ = max(valid_max_item, valid_max_)

            loss = criterion(output, y)
            lstm_last5_valid_pred = [0 if i < 0.5 else 1 for i in output]
            valid_loss += loss.detach().item()
            valid_correct += sum(torch.Tensor(lstm_last5_valid_pred)==y.cpu().detach()).item()
        valid_loss = valid_loss/len(valid_loader)
        lstm_last5_valid_loss_list.append(valid_loss)
        valid_acc = valid_correct/len(valid_dataset)
        lstm_last5_valid_acc_list.append(valid_acc)

        print("train max item = ", round(train_max_.item(), 4), ", valid max item = ", round(valid_max_.item(), 4))

        torch.save(bi_lstm_last5.state_dict(), lstm_last5_model_path)

        print(f"epoch {epoch+1} : train loss = {round(train_loss, 4)}, train acc = {train_correct}/{len(train_dataset)} ; valid loss = {round(valid_loss, 4)}, valid acc = {valid_correct}/{len(valid_dataset)}")
        if valid_loss < lowest_loss:
            lowest_loss = valid_loss
            early_stop_count = 0
            # torch.save(bi_lstm_last5.state_dict(), lstm_last5_model_path)
            # print(f"Save model at epoch {epoch+1} with valid loss = {round(valid_loss, 4)}")
        else:
            early_stop_count += 1
        
        if early_stop_count >= early_stop:
            print(f'Model is not improving, early stop at epoch {epoch+1}.')
            break

    if (epoch+1)%10 == 0:
        print(f'Epoch [{epoch+1}/{n_epoch}] : Train Loss : {round(train_loss, 4)}, Valid Loss : {round(valid_loss, 4)}')
# Out:
# train max item =  0.8676 , valid max item =  0.7472
# epoch 1 : train loss = 0.5504, train acc = 103296/105320 ; valid loss = 0.5308, valid acc = 29009/34362
# train max item =  0.7519 , valid max item =  0.7815
# epoch 2 : train loss = 0.4618, train acc = 102322/105320 ; valid loss = 0.5124, valid acc = 29861/34362
# train max item =  0.8138 , valid max item =  0.8924
# epoch 3 : train loss = 0.4533, train acc = 102441/105320 ; valid loss = 0.5356, valid acc = 29801/34362
# train max item =  0.8629 , valid max item =  0.882
# epoch 4 : train loss = 0.4498, train acc = 102606/105320 ; valid loss = 0.536, valid acc = 29588/34362
# train max item =  0.8762 , valid max item =  0.9269
# epoch 5 : train loss = 0.4471, train acc = 102584/105320 ; valid loss = 0.5389, valid acc = 29987/34362
# train max item =  0.9247 , valid max item =  0.9
# epoch 6 : train loss = 0.4447, train acc = 102455/105320 ; valid loss = 0.5415, valid acc = 29928/34362
# train max item =  0.9006 , valid max item =  0.9252
# epoch 7 : train loss = 0.443, train acc = 102341/105320 ; valid loss = 0.5487, valid acc = 29765/34362
# train max item =  0.9333 , valid max item =  0.9105
# epoch 8 : train loss = 0.4405, train acc = 102415/105320 ; valid loss = 0.5537, valid acc = 29560/34362
# train max item =  0.9607 , valid max item =  0.9308
# epoch 9 : train loss = 0.4385, train acc = 102264/105320 ; valid loss = 0.551, valid acc = 29759/34362
# train max item =  0.9293 , valid max item =  0.9127
# epoch 10 : train loss = 0.4374, train acc = 102287/105320 ; valid loss = 0.5475, valid acc = 29797/34362
# Epoch [10/250] : Train Loss : 0.4374, Valid Loss : 0.5475
# train max item =  0.941 , valid max item =  0.9435
# epoch 11 : train loss = 0.432, train acc = 102250/105320 ; valid loss = 0.5648, valid acc = 29464/34362
# train max item =  0.9566 , valid max item =  0.9512
# epoch 12 : train loss = 0.429, train acc = 102263/105320 ; valid loss = 0.5618, valid acc = 29595/34362
# train max item =  0.9673 , valid max item =  0.9683
# epoch 13 : train loss = 0.4237, train acc = 102456/105320 ; valid loss = 0.5412, valid acc = 30363/34362
# train max item =  0.9801 , valid max item =  0.9852
# epoch 14 : train loss = 0.4168, train acc = 102514/105320 ; valid loss = 0.5494, valid acc = 30114/34362
# train max item =  0.979 , valid max item =  0.9833
# epoch 15 : train loss = 0.4148, train acc = 102469/105320 ; valid loss = 0.5534, valid acc = 30308/34362
# train max item =  0.9964 , valid max item =  0.9886
# epoch 16 : train loss = 0.4136, train acc = 102598/105320 ; valid loss = 0.5496, valid acc = 30478/34362
# train max item =  0.9958 , valid max item =  0.9955
# epoch 17 : train loss = 0.408, train acc = 102576/105320 ; valid loss = 0.528, valid acc = 31047/34362
# train max item =  0.9899 , valid max item =  0.9905
# epoch 18 : train loss = 0.4006, train acc = 102822/105320 ; valid loss = 0.5221, valid acc = 31332/34362
# train max item =  0.9952 , valid max item =  0.9944
# epoch 19 : train loss = 0.3935, train acc = 102816/105320 ; valid loss = 0.5161, valid acc = 31732/34362
# train max item =  0.9973 , valid max item =  0.9934
# epoch 20 : train loss = 0.3871, train acc = 102914/105320 ; valid loss = 0.5245, valid acc = 31618/34362
# Epoch [20/250] : Train Loss : 0.3871, Valid Loss : 0.5245
# train max item =  0.9969 , valid max item =  0.996
# epoch 21 : train loss = 0.3827, train acc = 102911/105320 ; valid loss = 0.5487, valid acc = 31499/34362
# train max item =  0.9999 , valid max item =  0.9946
# epoch 22 : train loss = 0.3814, train acc = 102876/105320 ; valid loss = 0.5213, valid acc = 31922/34362
# train max item =  0.9996 , valid max item =  0.9974
# epoch 23 : train loss = 0.3784, train acc = 102913/105320 ; valid loss = 0.5484, valid acc = 31589/34362
# train max item =  0.999 , valid max item =  0.9967
# epoch 24 : train loss = 0.3729, train acc = 103101/105320 ; valid loss = 0.5286, valid acc = 32037/34362
# train max item =  0.9991 , valid max item =  0.9972
# epoch 25 : train loss = 0.3656, train acc = 103156/105320 ; valid loss = 0.5612, valid acc = 31945/34362
# train max item =  0.9992 , valid max item =  0.9956
# epoch 26 : train loss = 0.3586, train acc = 103235/105320 ; valid loss = 0.5444, valid acc = 32185/34362
# train max item =  0.9995 , valid max item =  0.9985
# epoch 27 : train loss = 0.3588, train acc = 103195/105320 ; valid loss = 0.5433, valid acc = 32182/34362
# train max item =  0.9975 , valid max item =  0.9994
# epoch 28 : train loss = 0.3583, train acc = 103273/105320 ; valid loss = 0.5479, valid acc = 32078/34362
# train max item =  0.9993 , valid max item =  0.9994
# epoch 29 : train loss = 0.3555, train acc = 103292/105320 ; valid loss = 0.5743, valid acc = 31910/34362
# train max item =  0.9992 , valid max item =  0.9984
# epoch 30 : train loss = 0.3517, train acc = 103276/105320 ; valid loss = 0.5403, valid acc = 32358/34362
# Epoch [30/250] : Train Loss : 0.3517, Valid Loss : 0.5403
# train max item =  0.9996 , valid max item =  0.9992
# epoch 31 : train loss = 0.347, train acc = 103453/105320 ; valid loss = 0.5683, valid acc = 32213/34362
# train max item =  0.9998 , valid max item =  0.9973
# epoch 32 : train loss = 0.3415, train acc = 103359/105320 ; valid loss = 0.5861, valid acc = 32066/34362
# train max item =  0.9998 , valid max item =  0.9965
# epoch 33 : train loss = 0.3384, train acc = 103364/105320 ; valid loss = 0.5989, valid acc = 32148/34362
# train max item =  0.9997 , valid max item =  0.9988
# epoch 34 : train loss = 0.34, train acc = 103447/105320 ; valid loss = 0.6004, valid acc = 32120/34362
# train max item =  0.9999 , valid max item =  0.9997
# epoch 35 : train loss = 0.3397, train acc = 103403/105320 ; valid loss = 0.5719, valid acc = 32291/34362
# train max item =  0.9997 , valid max item =  0.9998
# epoch 36 : train loss = 0.337, train acc = 103443/105320 ; valid loss = 0.5925, valid acc = 32204/34362
# train max item =  0.9999 , valid max item =  0.9996
# epoch 37 : train loss = 0.3359, train acc = 103470/105320 ; valid loss = 0.559, valid acc = 32508/34362
# train max item =  0.9997 , valid max item =  0.9992
# epoch 38 : train loss = 0.335, train acc = 103445/105320 ; valid loss = 0.5861, valid acc = 32361/34362
# train max item =  0.9999 , valid max item =  0.9989
# epoch 39 : train loss = 0.3322, train acc = 103472/105320 ; valid loss = 0.5624, valid acc = 32422/34362
# train max item =  0.9999 , valid max item =  0.9996
# epoch 40 : train loss = 0.3328, train acc = 103434/105320 ; valid loss = 0.5974, valid acc = 32278/34362
# Epoch [40/250] : Train Loss : 0.3328, Valid Loss : 0.5974
# train max item =  1.0 , valid max item =  0.9995
# epoch 41 : train loss = 0.336, train acc = 103477/105320 ; valid loss = 0.593, valid acc = 32406/34362
# train max item =  0.9998 , valid max item =  0.9994
# epoch 42 : train loss = 0.3315, train acc = 103468/105320 ; valid loss = 0.6337, valid acc = 32212/34362
# train max item =  0.9998 , valid max item =  0.9996
# epoch 43 : train loss = 0.3342, train acc = 103444/105320 ; valid loss = 0.6235, valid acc = 31900/34362
# train max item =  0.9999 , valid max item =  0.9999
# epoch 44 : train loss = 0.3319, train acc = 103448/105320 ; valid loss = 0.6454, valid acc = 31712/34362
# train max item =  0.9999 , valid max item =  0.9995
# epoch 45 : train loss = 0.3286, train acc = 103415/105320 ; valid loss = 0.6397, valid acc = 31930/34362
# train max item =  0.9999 , valid max item =  0.9999
# epoch 46 : train loss = 0.3326, train acc = 103338/105320 ; valid loss = 0.6376, valid acc = 31907/34362
# train max item =  0.9999 , valid max item =  1.0
# epoch 47 : train loss = 0.332, train acc = 103425/105320 ; valid loss = 0.6258, valid acc = 31904/34362
# train max item =  0.9999 , valid max item =  0.9999
# epoch 48 : train loss = 0.3298, train acc = 103464/105320 ; valid loss = 0.6058, valid acc = 32226/34362
# train max item =  0.9999 , valid max item =  0.9999
# epoch 49 : train loss = 0.3234, train acc = 103472/105320 ; valid loss = 0.6276, valid acc = 32254/34362
# train max item =  1.0 , valid max item =  0.9998
# epoch 50 : train loss = 0.3197, train acc = 103523/105320 ; valid loss = 0.634, valid acc = 32391/34362
# Epoch [50/250] : Train Loss : 0.3197, Valid Loss : 0.634
# train max item =  1.0 , valid max item =  0.9999
# epoch 51 : train loss = 0.3177, train acc = 103621/105320 ; valid loss = 0.642, valid acc = 32199/34362
# train max item =  1.0 , valid max item =  0.9998
# epoch 52 : train loss = 0.3163, train acc = 103530/105320 ; valid loss = 0.638, valid acc = 32353/34362
# Model is not improving, early stop at epoch 52.

# %% [markdown]
# ##### Loss Curve

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(12,4))
ax1.set_title("bidirectional LSTM (with last 5) Loss")
ax1.set_xlabel("epoch")
ax1.set_ylabel("loss")
ax1.plot(lstm_last5_train_loss_list, label="train loss")
ax1.plot(lstm_last5_valid_loss_list, label="valid loss")
ax1.legend()
ax2.set_title("bidirectional LSTM (with last 5) Acc")
ax2.set_xlabel("epoch")
ax2.set_ylabel("acc")
ax2.plot(lstm_last5_train_acc_list, label="train acc")
ax2.plot(lstm_last5_valid_acc_list, label="valid acc")
ax2.legend()

# %% [markdown]
# ##### ROC & PRC

# %%
bi_lstm_last5 = bi_LSTM(hidden_size=128, num_layers=1)
bi_lstm_last5.load_state_dict(torch.load(lstm_last5_model_path))
bi_lstm_last5.eval().to(device)
lstm_last5_train_loss, lstm_last5_train_proba = 0, []
lstm_last5_valid_loss, lstm_last5_valid_proba = 0, []
lstm_last5_test_loss, lstm_last5_test_proba = 0, []
with torch.no_grad():
    for x, y in tqdm(train_loader_last5):
        x, y = x.float().to(device), y.float().to(device)
        output = bi_lstm_last5(x)
        loss = criterion(output, y)
        lstm_last5_train_loss += loss.detach().item()
        lstm_last5_train_proba += output.tolist()
    lstm_last5_train_proba = torch.sigmoid(torch.Tensor(lstm_last5_train_proba))
    lstm_last5_train_pred = [1 if prob >= 0.5 else 0 for prob in lstm_last5_train_proba]
    lstm_last5_train_loss = lstm_last5_train_loss/len(train_loader_last5)
    print(f"train loss : {lstm_last5_train_loss}")
    for x, y in tqdm(valid_loader_last5):
        x, y = x.float().to(device), y.float().to(device)
        output = bi_lstm_last5(x)
        loss = criterion(output, y)
        lstm_last5_valid_loss += loss.detach().item()
        lstm_last5_valid_proba += output.tolist()
    lstm_last5_valid_proba = torch.sigmoid(torch.Tensor(lstm_last5_valid_proba))
    lstm_last5_valid_pred = [1 if prob >= 0.5 else 0 for prob in lstm_last5_valid_proba]
    lstm_last5_valid_loss = lstm_last5_valid_loss/len(valid_loader_last5)
    print(f"valid loss : {lstm_last5_valid_loss}")
    for x, y in tqdm(test_loader_last5):
        x, y = x.float().to(device), y.float().to(device)
        output = bi_lstm_last5(x)
        loss = criterion(output, y)
        lstm_last5_test_loss += loss.detach().item()
        lstm_last5_test_proba += output.tolist()
    lstm_last5_test_proba = torch.sigmoid(torch.Tensor(lstm_last5_test_proba))
    lstm_last5_test_pred = [1 if prob >= 0.5 else 0 for prob in lstm_last5_test_proba]
    lstm_last5_test_loss = lstm_last5_test_loss/len(test_loader_last5)
    print(f"test loss : {lstm_last5_test_loss}")
# Out:
# 100%|██████████| 103/103 [00:00<00:00, 124.32it/s]
# train loss : 0.3091292660502554
# 100%|██████████| 34/34 [00:00<00:00, 136.54it/s]
# valid loss : 0.6380004751331666
# 100%|██████████| 11/11 [00:00<00:00, 146.04it/s]
# test loss : 0.7654121924530376

# %%
plot_curve_(train_dataset.y, np.array(lstm_last5_train_proba), "bi-LSTM (last 5) on train set")

# %%
plot_curve_(valid_dataset.y, np.array(lstm_last5_valid_proba), "bi-LSTM (last 5) on valid set")

# %%
plot_curve_(test_dataset.y, np.array(lstm_last5_test_proba), "bi-LSTM (last 5) on test set")

# %%
plot_confusion_matrix(test_dataset.y, lstm_last5_test_pred, "bi-LSTM (last 5)")
